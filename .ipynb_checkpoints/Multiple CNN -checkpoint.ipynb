# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\FraudDetectionData.csv")

# %%
import pandas as pd

# Count the number of 0s and 1s in the 'isFraud' column
fraud_counts = df['isFraud'].value_counts()

# Print the result
print(fraud_counts)
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['type'])
label
df.drop("type", axis=1, inplace=True)
df["type"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['nameDest'])
label
df.drop("nameDest", axis=1, inplace=True)
df["nameDest"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['nameOrig'])
label
df.drop("nameOrig", axis=1, inplace=True)
df["nameOrig"] = label

# %%
X = df.drop('isFraud', axis=1)
# Separate the target variable
y = df['isFraud']

# %%
from imblearn.over_sampling import SMOTE

#Upsampling via SMOTE
smote = SMOTE(sampling_strategy=0.55, random_state=0)

# Fit and apply the resampler to the entire dataset
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
counts = y_resampled.value_counts()
print(counts)
# Out:
# 0    6354407
# 1    3494923
# Name: isFraud, dtype: int64

# %% [markdown]
# ## Reservoir sampling without replacement

# %%
import csv
import random

# number of data points to sample from original dataset
k= 1500000

def reservoir_sampling(iterable, k, header=True):
    reservoir = []
    for i, item in enumerate(iterable):
        if i < k:
            reservoir.append(item)
        else:
            j = random.randint(0, i)
            if j < k:
                reservoir[j] = item
    return reservoir

# Open the input CSV file
with open(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\FraudDetectionData.csv") as f:
    # Check if header line exists
    header = True
    first_line = f.readline()
    if not first_line.startswith('step,type,amount,nameOrig,oldbalanceOrg,newbalanceOrig,nameDest,oldbalanceDest,newbalanceDest,isFraud,isFlaggedFraud'):
        header = False
        f.seek(0)  # Rewind file pointer to beginning

    # Sample from remaining lines
    sampled_lines = []
    for i, line in enumerate(f):
        if i < k:
            sampled_lines.append(line)
        else:
            j = random.randint(0, i)
            if j < k:
                sampled_lines[j] = line

# Open the output CSV file and write the subsample to it
with open(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\transfer_learning.csv", mode='w', newline='') as f:
    writer = csv.writer(f)
    if header:
        writer.writerow(first_line.strip().split(','))
    for line in sampled_lines:
        writer.writerow(line.strip().split(','))

# %% [markdown]
# https://towardsdatascience.com/generating-expanding-your-datasets-with-synthetic-data-4e27716be218

# %% [markdown]
# ## Pre-process larger dataset

# %%
df_sample_big=pd.read_csv(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\transfer_learning.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample_big['type'])
label
df_sample_big.drop("type", axis=1, inplace=True)
df_sample_big["type"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample_big['nameDest'])
label
df_sample_big.drop("nameDest", axis=1, inplace=True)
df_sample_big["nameDest"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample_big['nameOrig'])
label
df_sample_big.drop("nameOrig", axis=1, inplace=True)
df_sample_big["nameOrig"] = label

# %%
from sklearn.model_selection import train_test_split

X = df_sample_big.drop('isFraud', axis=1)
# Separate the target variable
y = df_sample_big['isFraud']

# Print class distribution before split
print(y.value_counts(normalize=True))

from sklearn.model_selection import train_test_split

# Assuming X contains your features and y contains your target variable
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1, stratify=y_resampled, random_state=2)

# Print class distribution after split
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# 0    0.998725
# 1    0.001275
# Name: isFraud, dtype: float64
# 0    0.645161
# 1    0.354839
# Name: isFraud, dtype: float64
# 0    0.645162
# 1    0.354838
# Name: isFraud, dtype: float64

# %%
from imblearn.under_sampling import TomekLinks

#Resample using TomekLinks first
tomek_links = TomekLinks(sampling_strategy='majority')
X_train_resampled, y_train_resampled = tomek_links.fit_resample(X_train, y_train)

# %%
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours,OneSidedSelection
# resample the output of TomekLinks using EditedNearestNeighbours
enn = EditedNearestNeighbours(sampling_strategy='majority')
X_train_resampled_new, y_train_resampled_new = enn.fit_resample(X_train_resampled, y_train_resampled)

# %%
from imblearn.under_sampling import OneSidedSelection
# resample the output of EditedNearestNeighbours using One-Sided Selection
oss = OneSidedSelection(sampling_strategy='majority')
X_train_resampled_final, y_train_resampled_final = oss.fit_resample(X_train_resampled_new, y_train_resampled_new)

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
# convert X_test to a pandas dataframe
X_test = pd.DataFrame(X_test, columns=X_train.columns)
# define a function to replace outliers with MAD for a single column
def replace_outliers_with_mad(column):
    median = np.median(column)
    mad = np.median(np.abs(column - median))
    threshold = 2.5 * mad
    column[np.abs(column - median) > threshold] = median
    return column

# apply the function to all columns of X_train_resampled_final
for i in range(X_train_resampled_final.shape[1]):
    X_train_resampled_final.iloc[:, i] = replace_outliers_with_mad(X_train_resampled_final.iloc[:, i])

# apply the function to all columns of X_test
for i in range(X_test.shape[1]):
    X_test.iloc[:, i] = replace_outliers_with_mad(X_test.iloc[:, i])

# convert the numpy arrays back to pandas dataframes
X_train_resampled_final = pd.DataFrame(X_train_resampled_final, columns=X_train.columns)
X_test = pd.DataFrame(X_test, columns=X_test.columns)

# print the modified dataframes
print(X_train_resampled_final)
print(X_test)
# Out:
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#          step         amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0          12   45298.350000       0.000000             0.0     5256.196317
# 1         144    9664.660000     135.000000             0.0        0.000000
# 2         212    3535.920000  101588.000000             0.0        0.000000
# 3         284   18362.990000   25965.350000             0.0     5256.196317
# 4         349  137418.000000       0.000000             0.0     5256.196317
# ...       ...            ...            ...             ...             ...
# 8829074    93  137418.000000   62726.000000             0.0     5256.196317
# 8829075   285  137418.000000   62726.000000             0.0       32.745541
# 8829076   327  137418.000000   62726.000000             0.0     5256.196317
# 8829077   323  100140.215276  100140.215276             0.0        0.000000
# 8829078   409  165893.714023  165893.714023             0.0        0.000000
#
#          newbalanceDest  isFlaggedFraud  type  nameDest  nameOrig
# 0             147956.77               0     1    122907   4667844
# 1                  0.00               0     3    363294   4689675
# 2                  0.00               0     3    363294   6273104
# 3             454376.74               0     1    219987   3794825
# 4             147956.77               0     1     74881   4634690
# ...                 ...             ...   ...       ...       ...
# 8829074       147956.77               0     1    512921   4287954
# 8829075       147956.77               0     1    172487   4600375
# 8829076       147956.77               0     1    398384   6175542
# 8829077            0.00               0     1    520687   4995382
# 8829078            0.00               0     1    259919   5022268
#
# [8829079 rows x 10 columns]
#          step         amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2360459   190   21833.020000   92575.000000             0.0        0.000000
# 8700837   279  137045.460000   62889.650000             0.0     6164.889532
# 521794     20  129859.140000   61526.000000             0.0        0.000000
# 4379310   311    9871.080000   32601.000000             0.0        0.000000
# 4114157   302  238620.050000   62889.650000             0.0     6164.889532
# ...       ...            ...            ...             ...             ...
# 2373669   191    6478.050000       0.000000             0.0        0.000000
# 7789754   482  172469.674581  172469.674581             0.0        0.000000
# 8995101   470  137045.460000   62889.650000             0.0        0.000000
# 1976688   178  137045.460000       0.000000             0.0     6164.889532
# 6974382   371  239589.729651   62889.650000             0.0     6164.889532
#
#          newbalanceDest  isFlaggedFraud  type  nameDest  nameOrig
# 2360459        0.000000               0     3    362801   2819095
# 8700837   150045.630000               0     1    398262   5440294
# 521794    129859.140000               0     1    389130    389004
# 4379310        0.000000               0     3    362801   2437025
# 4114157   150045.630000               0     0    305716   5493566
# ...                 ...             ...   ...       ...       ...
# 2373669        0.000000               0     3    362801   2471315
# 7789754        0.000000               0     1    112757   5355854
# 8995101        0.000000               0     1    310868   4216750
# 1976688   150045.630000               0     1    190848   5951678
# 6974382   380421.008028               0     1    419322   1373766
#
# [984933 rows x 10 columns]

# %%
# import module
from sklearn.preprocessing import StandardScaler

# compute required values
scaler = StandardScaler()
model = scaler.fit(X_train_resampled_final)
X_train_resampled_final = model.transform(X_train_resampled_final)

# %%
# compute required values
scaler = StandardScaler()
model = scaler.fit(X_test)
X_test = model.transform(X_test)

# %%
df_sample_big = df_sample_big.reset_index(drop=True)

# %% [markdown]
# ### Big dataset: Pre-train CNN

# %%
import time
import numpy as np

from keras import regularizers
from keras.models import Sequential
from keras.regularizers import l1
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dropout
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization

# define number of folds for cross-validation
num_folds = 2

# create KFold cross-validation object
kfold = KFold(n_splits=num_folds, shuffle=True)

# create arrays to store training and validation loss for each epoch
train_losses = np.zeros((num_folds, 4))
val_losses = np.zeros((num_folds, 4))

# loop over the folds
fold_no = 1
for train, val in kfold.split(X_train_resampled_final, y_train_resampled_final): 

    # create model
    pre_trained_model = Sequential()
    # add convolutional layer
    pre_trained_model.add(Conv1D(filters=16, kernel_size=2, input_shape=(10, 1)))
    # add batch normalization layer
    pre_trained_model.add(BatchNormalization())
    # add activation function
    pre_trained_model.add(Conv1D(8, 2, activation='tanh'))
    pre_trained_model.add(BatchNormalization())
    # add pooling layer
    pre_trained_model.add(MaxPooling1D(pool_size=2))
    # flatten output to feed into fully connected layer
    pre_trained_model.add(Flatten()) 
    # add fully connected layer
    pre_trained_model.add(Dense(5, activation='tanh', kernel_regularizer=l1(0.0001714)))
    # add dropout layer
    layer = Dropout(0.1)
    pre_trained_model.add(layer)
    # add output layer
    pre_trained_model.add(Dense(1, activation='sigmoid'))
    
    opt_new = keras.optimizers.RMSprop(learning_rate=0.000871)
    # opt_new = keras.optimizers.Adam(learning_rate=0.0171)

    # compile model
    pre_trained_model.compile(loss='binary_crossentropy', optimizer=opt_new, metrics=['accuracy'])
    
    # record start time
    start_time = time.time()
    
    from sklearn.utils.class_weight import compute_class_weight

    # train model for each fold
    history = pre_trained_model.fit(X_train_resampled_final[train], y_train_resampled_final[train],
                                     epochs=4, batch_size=32, validation_data=(X_train_resampled_final[val], y_train_resampled_final[val]))
    
    # record end time and calculate elapsed time
    end_time = time.time()
    elapsed_time = end_time - start_time
    
    print(f'Fold {fold_no} elapsed time: {elapsed_time:.2f} seconds')
    
    from sklearn.metrics import classification_report

    # make predictions on validation set
    y_pred = pre_trained_model.predict(X_train_resampled_final[val])

    # convert predictions to binary labels
    y_pred = np.round(y_pred)

    # print classification report
    print(classification_report(y_train_resampled_final[val], y_pred))
    
    # store training and validation loss for each epoch
    train_losses[fold_no-1] = history.history['loss']
    val_losses[fold_no-1] = history.history['val_loss']
    
    # increment fold number
    fold_no += 1
    
# calculate mean training and validation loss across all folds for each epoch
mean_train_loss = np.mean(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)

# plot training and validation loss curves for each epoch
plt.plot(mean_train_loss, label='Training Loss')
plt.plot(mean_val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/4
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018E9BDB0288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018E9BDB0288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137950/137955 [============================>.] - ETA: 0s - loss: 0.1323 - accuracy: 0.9512WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018E975A4678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018E975A4678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137955/137955 [==============================] - 820s 6ms/step - loss: 0.1323 - accuracy: 0.9512 - val_loss: 0.1016 - val_accuracy: 0.9656
# Epoch 2/4
# 137955/137955 [==============================] - 690s 5ms/step - loss: 0.1176 - accuracy: 0.9606 - val_loss: 0.0981 - val_accuracy: 0.9671
# Epoch 3/4
# 137955/137955 [==============================] - 599s 4ms/step - loss: 0.1109 - accuracy: 0.9630 - val_loss: 0.0947 - val_accuracy: 0.9685
# Epoch 4/4
# 137955/137955 [==============================] - 520s 4ms/step - loss: 0.1061 - accuracy: 0.9649 - val_loss: 0.0891 - val_accuracy: 0.9712
# Fold 1 elapsed time: 2630.02 seconds
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018E9E0F10D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018E9E0F10D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137955/137955 [==============================] - 212s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98   2841673
#            1       0.94      0.98      0.96   1572867
#
#     accuracy                           0.97   4414540
#    macro avg       0.96      0.97      0.97   4414540
# weighted avg       0.97      0.97      0.97   4414540
#
# Epoch 1/4
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018E99F8E168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018E99F8E168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137955/137955 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9511WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018EA3873798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018EA3873798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137955/137955 [==============================] - 659s 5ms/step - loss: 0.1318 - accuracy: 0.9511 - val_loss: 0.1114 - val_accuracy: 0.9630
# Epoch 2/4
# 137955/137955 [==============================] - 586s 4ms/step - loss: 0.1207 - accuracy: 0.9575 - val_loss: 0.1065 - val_accuracy: 0.9645
# Epoch 3/4
# 137955/137955 [==============================] - 747s 5ms/step - loss: 0.1203 - accuracy: 0.9584 - val_loss: 0.1072 - val_accuracy: 0.9644
# Epoch 4/4
# 137955/137955 [==============================] - 725s 5ms/step - loss: 0.1201 - accuracy: 0.9591 - val_loss: 0.0966 - val_accuracy: 0.9724
# Fold 2 elapsed time: 2719.12 seconds
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018EAEC2C3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018EAEC2C3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137955/137955 [==============================] - 274s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98   2841975
#            1       0.94      0.98      0.96   1572564
#
#     accuracy                           0.97   4414539
#    macro avg       0.97      0.97      0.97   4414539
# weighted avg       0.97      0.97      0.97   4414539

# %%
pre_trained_model.save('pre_trained_model.h5')

# %% [markdown]
# ## 2nd pre-trained CNN

# %%
import csv
import random

# number of data points to sample from original dataset
k2= 2200000

def reservoir_sampling(iterable, k, header=True):
    reservoir = []
    for i, item in enumerate(iterable):
        if i < k2:
            reservoir.append(item)
        else:
            j = random.randint(0, i)
            if j < k2:
                reservoir[j] = item
    return reservoir

# Open the input CSV file
with open(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\FraudDetectionData.csv") as f:
    # Check if header line exists
    header = True
    first_line = f.readline()
    if not first_line.startswith('step,type,amount,nameOrig,oldbalanceOrg,newbalanceOrig,nameDest,oldbalanceDest,newbalanceDest,isFraud,isFlaggedFraud'):
        header = False
        f.seek(0)  # Rewind file pointer to beginning

    # Sample from remaining lines
    sampled_lines = []
    for i, line in enumerate(f):
        if i < k2:
            sampled_lines.append(line)
        else:
            j = random.randint(0, i)
            if j < k2:
                sampled_lines[j] = line

# Open the output CSV file and write the subsample to it
with open(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\transfer_learning_2.csv", mode='w', newline='') as f:
    writer = csv.writer(f)
    if header:
        writer.writerow(first_line.strip().split(','))
    for line in sampled_lines:
        writer.writerow(line.strip().split(','))

# %%
df_sample_mid=pd.read_csv(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\transfer_learning_2.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample_mid['type'])
label
df_sample_mid.drop("type", axis=1, inplace=True)
df_sample_mid["type"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample_mid['nameDest'])
label
df_sample_mid.drop("nameDest", axis=1, inplace=True)
df_sample_mid["nameDest"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample_mid['nameOrig'])
label
df_sample_mid.drop("nameOrig", axis=1, inplace=True)
df_sample_mid["nameOrig"] = label

# %%
from sklearn.model_selection import train_test_split

X = df_sample_mid.drop('isFraud', axis=1)
# Separate the target variable
y = df_sample_mid['isFraud']

# Print class distribution before split
print(y.value_counts(normalize=True))

from sklearn.model_selection import train_test_split

# Assuming X contains your features and y contains your target variable
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1, stratify=y_resampled, random_state=2)

# Print class distribution after split
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# 0    0.998698
# 1    0.001302
# Name: isFraud, dtype: float64
# 0    0.645161
# 1    0.354839
# Name: isFraud, dtype: float64
# 0    0.645162
# 1    0.354838
# Name: isFraud, dtype: float64

# %%
from imblearn.under_sampling import TomekLinks

#Resample using TomekLinks first
tomek_links = TomekLinks(sampling_strategy='majority')
X_train_resampled, y_train_resampled = tomek_links.fit_resample(X_train, y_train)

# %%
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours,OneSidedSelection
# resample the output of TomekLinks using EditedNearestNeighbours
enn = EditedNearestNeighbours(sampling_strategy='majority')
X_train_resampled_new, y_train_resampled_new = enn.fit_resample(X_train_resampled, y_train_resampled)

# %%
from imblearn.under_sampling import OneSidedSelection
# resample the output of EditedNearestNeighbours using One-Sided Selection
oss = OneSidedSelection(sampling_strategy='majority')
X_train_resampled_final, y_train_resampled_final = oss.fit_resample(X_train_resampled_new, y_train_resampled_new)

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
# convert X_test to a pandas dataframe
X_test = pd.DataFrame(X_test, columns=X_train.columns)
# define a function to replace outliers with MAD for a single column
def replace_outliers_with_mad(column):
    median = np.median(column)
    mad = np.median(np.abs(column - median))
    threshold = 2.5 * mad
    column[np.abs(column - median) > threshold] = median
    return column

# apply the function to all columns of X_train_resampled_final
for i in range(X_train_resampled_final.shape[1]):
    X_train_resampled_final.iloc[:, i] = replace_outliers_with_mad(X_train_resampled_final.iloc[:, i])

# apply the function to all columns of X_test
for i in range(X_test.shape[1]):
    X_test.iloc[:, i] = replace_outliers_with_mad(X_test.iloc[:, i])

# convert the numpy arrays back to pandas dataframes
X_train_resampled_final = pd.DataFrame(X_train_resampled_final, columns=X_train.columns)
X_test = pd.DataFrame(X_test, columns=X_test.columns)

# print the modified dataframes
print(X_train_resampled_final)
print(X_test)
# Out:
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#          step         amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         305   34224.550000  172122.000000             0.0     5235.661962
# 1         144    9664.660000     135.000000             0.0        0.000000
# 2         212    3535.920000  101588.000000             0.0        0.000000
# 3         284   18362.990000   25965.350000             0.0     5235.661962
# 4         349  137404.136742       0.000000             0.0     5235.661962
# ...       ...            ...            ...             ...             ...
# 8828545    93  137404.136742   62682.283544             0.0     5235.661962
# 8828546   285  137404.136742   62682.283544             0.0       32.745541
# 8828547   327  137404.136742   62682.283544             0.0     5235.661962
# 8828548   323  100140.215276  100140.215276             0.0        0.000000
# 8828549   409  165893.714023  165893.714023             0.0        0.000000
#
#          newbalanceDest  isFlaggedFraud  type  nameDest  nameOrig
# 0            147908.385               0     1    187632   6144589
# 1                 0.000               0     3    363315   4689675
# 2                 0.000               0     3    363315   6273104
# 3            454376.740               0     1    219987   3794825
# 4            147908.385               0     1     74881   4634690
# ...                 ...             ...   ...       ...       ...
# 8828545      147908.385               0     1    512921   4287954
# 8828546      147908.385               0     1    172487   4600375
# 8828547      147908.385               0     1    398384   6175542
# 8828548           0.000               0     1    520687   4995382
# 8828549           0.000               0     1    259919   5022268
#
# [8828550 rows x 10 columns]
#          step         amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2360459   190   21833.020000   92575.000000             0.0        0.000000
# 8700837   279  137045.460000   62889.650000             0.0     6164.889532
# 521794     20  129859.140000   61526.000000             0.0        0.000000
# 4379310   311    9871.080000   32601.000000             0.0        0.000000
# 4114157   302  238620.050000   62889.650000             0.0     6164.889532
# ...       ...            ...            ...             ...             ...
# 2373669   191    6478.050000       0.000000             0.0        0.000000
# 7789754   482  172469.674581  172469.674581             0.0        0.000000
# 8995101   470  137045.460000   62889.650000             0.0        0.000000
# 1976688   178  137045.460000       0.000000             0.0     6164.889532
# 6974382   371  239589.729651   62889.650000             0.0     6164.889532
#
#          newbalanceDest  isFlaggedFraud  type  nameDest  nameOrig
# 2360459        0.000000               0     3    362801   2819095
# 8700837   150045.630000               0     1    398262   5440294
# 521794    129859.140000               0     1    389130    389004
# 4379310        0.000000               0     3    362801   2437025
# 4114157   150045.630000               0     0    305716   5493566
# ...                 ...             ...   ...       ...       ...
# 2373669        0.000000               0     3    362801   2471315
# 7789754        0.000000               0     1    112757   5355854
# 8995101        0.000000               0     1    310868   4216750
# 1976688   150045.630000               0     1    190848   5951678
# 6974382   380421.008028               0     1    419322   1373766
#
# [984933 rows x 10 columns]

# %%
# import module
from sklearn.preprocessing import StandardScaler

# compute required values
scaler = StandardScaler()
model = scaler.fit(X_train_resampled_final)
X_train_resampled_final = model.transform(X_train_resampled_final)

# %%
# compute required values
scaler = StandardScaler()
model = scaler.fit(X_test)
X_test = model.transform(X_test)

# %%
df_sample_mid = df_sample_mid.reset_index(drop=True)

# %% [markdown]
# ## Train 2nd CNN

# %%
import time
import numpy as np

from keras import regularizers
from keras.models import Sequential
from keras.regularizers import l1
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dropout
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization

# define number of folds for cross-validation
num_folds = 2

# create KFold cross-validation object
kfold = KFold(n_splits=num_folds, shuffle=True)

# create arrays to store training and validation loss for each epoch
train_losses = np.zeros((num_folds, 4))
val_losses = np.zeros((num_folds, 4))

# loop over the folds
fold_no = 1
for train, val in kfold.split(X_train_resampled_final, y_train_resampled_final): 

    # create model
    pre_trained_model = Sequential()
    # add convolutional layer
    pre_trained_model.add(Conv1D(filters=16, kernel_size=2, input_shape=(10, 1), kernel_regularizer=l1(0.001)))
    # add dropout layer
    layer = Dropout(0.1)
    pre_trained_model.add(layer)
    # flatten output to feed into fully connected layer
    pre_trained_model.add(Flatten()) 
    # add fully connected layer
    pre_trained_model.add(Dense(7, activation='tanh', kernel_regularizer=l1(0.000124)))
    # add output layer
    pre_trained_model.add(Dense(1, activation='sigmoid'))
    
    opt_new = keras.optimizers.RMSprop(learning_rate=0.000911)
    # opt_new = keras.optimizers.Adam(learning_rate=0.0171)

    # compile model
    pre_trained_model.compile(loss='binary_crossentropy', optimizer=opt_new, metrics=['accuracy'])
    
    # record start time
    start_time = time.time()
    
    from sklearn.utils.class_weight import compute_class_weight

    # train model for each fold
    history = pre_trained_model.fit(X_train_resampled_final[train], y_train_resampled_final[train],
                                     epochs=4, batch_size=32, validation_data=(X_train_resampled_final[val], y_train_resampled_final[val]))
    
    # record end time and calculate elapsed time
    end_time = time.time()
    elapsed_time = end_time - start_time
    
    print(f'Fold {fold_no} elapsed time: {elapsed_time:.2f} seconds')
    
    from sklearn.metrics import classification_report

    # make predictions on validation set
    y_pred = pre_trained_model.predict(X_train_resampled_final[val])

    # convert predictions to binary labels
    y_pred = np.round(y_pred)

    # print classification report
    print(classification_report(y_train_resampled_final[val], y_pred))
    
    # store training and validation loss for each epoch
    train_losses[fold_no-1] = history.history['loss']
    val_losses[fold_no-1] = history.history['val_loss']
    
    # increment fold number
    fold_no += 1
    
# calculate mean training and validation loss across all folds for each epoch
mean_train_loss = np.mean(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)

# plot training and validation loss curves for each epoch
plt.plot(mean_train_loss, label='Training Loss')
plt.plot(mean_val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/4
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018EA8091F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018EA8091F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137928/137947 [============================>.] - ETA: 0s - loss: 0.1834 - accuracy: 0.9346WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018EC56C4678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018EC56C4678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137947/137947 [==============================] - 572s 4ms/step - loss: 0.1834 - accuracy: 0.9346 - val_loss: 0.1497 - val_accuracy: 0.9493
# Epoch 2/4
# 137947/137947 [==============================] - 655s 5ms/step - loss: 0.1259 - accuracy: 0.9643 - val_loss: 0.1025 - val_accuracy: 0.9743
# Epoch 3/4
# 137947/137947 [==============================] - 728s 5ms/step - loss: 0.1127 - accuracy: 0.9711 - val_loss: 0.1008 - val_accuracy: 0.9756
# Epoch 4/4
# 137947/137947 [==============================] - 632s 5ms/step - loss: 0.1110 - accuracy: 0.9723 - val_loss: 0.1019 - val_accuracy: 0.9754
# Fold 1 elapsed time: 2589.18 seconds
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018E9E0E8D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018E9E0E8D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137947/137947 [==============================] - 165s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98   2841770
#            1       0.95      0.99      0.97   1572505
#
#     accuracy                           0.98   4414275
#    macro avg       0.97      0.98      0.97   4414275
# weighted avg       0.98      0.98      0.98   4414275
#
# Epoch 1/4
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018E9EF6EA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000018E9EF6EA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137944/137947 [============================>.] - ETA: 0s - loss: 0.1621 - accuracy: 0.9466WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018EC5795168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000018EC5795168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137947/137947 [==============================] - 410s 3ms/step - loss: 0.1621 - accuracy: 0.9466 - val_loss: 0.1068 - val_accuracy: 0.9709
# Epoch 2/4
# 137947/137947 [==============================] - 392s 3ms/step - loss: 0.1166 - accuracy: 0.9667 - val_loss: 0.1024 - val_accuracy: 0.9717
# Epoch 3/4
# 137947/137947 [==============================] - 394s 3ms/step - loss: 0.1158 - accuracy: 0.9672 - val_loss: 0.1031 - val_accuracy: 0.9730
# Epoch 4/4
# 137947/137947 [==============================] - 392s 3ms/step - loss: 0.1160 - accuracy: 0.9674 - val_loss: 0.1035 - val_accuracy: 0.9716
# Fold 2 elapsed time: 1589.02 seconds
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018EC5812F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000018EC5812F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 137947/137947 [==============================] - 152s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98   2841349
#            1       0.94      0.98      0.96   1572926
#
#     accuracy                           0.97   4414275
#    macro avg       0.97      0.97      0.97   4414275
# weighted avg       0.97      0.97      0.97   4414275

# %% [markdown]
# ## Go back to smaller dataset

# %%
import numpy as np
import pandas as pd
df_sample=pd.read_csv(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\sample.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['type'])
label
df_sample.drop("type", axis=1, inplace=True)
df_sample["type"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['nameDest'])
label
df_sample.drop("nameDest", axis=1, inplace=True)
df_sample["nameDest"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['nameOrig'])
label
df_sample.drop("nameOrig", axis=1, inplace=True)
df_sample["nameOrig"] = label

# %%
X = df_sample.drop('isFraud', axis=1)
# Separate the target variable
y = df_sample['isFraud']

# %%
from imblearn.over_sampling import SMOTE

#Upsampling via SMOTE
smote = SMOTE(sampling_strategy=0.55, random_state=0)

# Fit and apply the resampler to the entire dataset
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
# from sklearn.model_selection import train_test_split

# X = df_sample.drop('isFraud', axis=1)
# # Separate the target variable
# y = df_sample['isFraud']

# # Print class distribution before split
# print(y.value_counts(normalize=True))

from sklearn.model_selection import train_test_split

# Assuming X contains your features and y contains your target variable
X_train, X_test, y_train, y_test = train_test_split(X_resampled,  y_resampled, test_size=0.1, stratify= y_resampled, random_state=2)

# Print class distribution after split
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# 0    0.645162
# 1    0.354838
# Name: isFraud, dtype: float64
# 0    0.645159
# 1    0.354841
# Name: isFraud, dtype: float64

# %%
from imblearn.under_sampling import TomekLinks

#Resample using TomekLinks first
tomek_links = TomekLinks(sampling_strategy='majority')
X_train_resampled, y_train_resampled = tomek_links.fit_resample(X_train, y_train)

# %%
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours,OneSidedSelection
# resample the output of TomekLinks using EditedNearestNeighbours
enn = EditedNearestNeighbours(sampling_strategy='majority')
X_train_resampled_new, y_train_resampled_new = enn.fit_resample(X_train_resampled, y_train_resampled)

# %%
from imblearn.under_sampling import OneSidedSelection
# resample the output of EditedNearestNeighbours using One-Sided Selection
oss = OneSidedSelection(sampling_strategy='majority')
X_train_resampled_final, y_train_resampled_final = oss.fit_resample(X_train_resampled_new, y_train_resampled_new)

# %%
df_sample = df_sample.reset_index(drop=True)

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
# convert X_test to a pandas dataframe
X_test = pd.DataFrame(X_test, columns=X_train.columns)
# define a function to replace outliers with MAD for a single column
def replace_outliers_with_mad(column):
    median = np.median(column)
    mad = np.median(np.abs(column - median))
    threshold = 2.5 * mad
    column[np.abs(column - median) > threshold] = median
    return column

# apply the function to all columns of X_train_resampled_final
for i in range(X_train_resampled_final.shape[1]):
     X_train_resampled_final.iloc[:, i] = replace_outliers_with_mad(X_train_resampled_final.iloc[:, i])
   # X_train_resampled_final[:, i] = replace_outliers_with_mad(X_train_resampled_final[:, i])

# apply the function to all columns of X_test
for i in range(X_test.shape[1]):
    X_test.iloc[:, i] = replace_outliers_with_mad(X_test.iloc[:, i])

# convert the numpy arrays back to pandas dataframes
X_train_resampled_final = pd.DataFrame(X_train_resampled_final, columns=X_train.columns)
X_test = pd.DataFrame(X_test, columns=X_test.columns)

# print the modified dataframes
print(X_train_resampled_final)
print(X_test)
# Out:
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#         step         amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0        259  297414.970000   55464.752215             0.0     2892.584735
# 1        299  135755.710000       0.000000             0.0     2892.584735
# 2        214   40082.480000   55464.752215             0.0     2892.584735
# 3        229   72769.580000   43166.000000             0.0        0.000000
# 4        284   19306.770000       0.000000             0.0        0.000000
# ...      ...            ...            ...             ...             ...
# 947783   124  135755.710000   55464.752215             0.0        0.000000
# 947784   281  141996.285548  141996.285548             0.0     2892.584735
# 947785   305  135755.710000   55464.752215             0.0     2892.584735
# 947786   435  341707.785915   55464.752215             0.0     2892.584735
# 947787   486  135755.710000   55464.752215             0.0        0.000000
#
#         newbalanceDest  isFlaggedFraud  type  nameDest  nameOrig
# 0        142732.740000               0     0     51912    389975
# 1        144246.948939               0     1    202934    627621
# 2         14449.930000               0     0     22974    677921
# 3         72769.580000               0     1    154491    670050
# 4             0.000000               0     3    163443    106403
# ...                ...             ...   ...       ...       ...
# 947783   144246.948939               0     1     84744    604050
# 947784   270834.349422               0     1    164586    142360
# 947785   144246.948939               0     1    118470    411760
# 947786   144246.948939               0     1    170412    158105
# 947787   144246.948939               0     1    197990    192587
#
# [947788 rows x 10 columns]
#          step         amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 162757    328  230117.470000       0.000000             0.0    10713.613233
# 476897    395   15010.570000       0.000000             0.0    10713.613233
# 305893     16  244173.720000   20167.000000             0.0    10266.000000
# 11003     280    5335.170000   61909.500000             0.0        0.000000
# 920032    461   63680.344537   63680.344537             0.0    28242.349065
# ...       ...            ...            ...             ...             ...
# 684283    428    7598.630000   82228.000000             0.0        0.000000
# 530816    188  324406.230000       0.000000             0.0    10713.613233
# 1014827   280  134603.595449   61909.500000             0.0    10713.613233
# 980792    440   91052.149907   91052.149907             0.0        0.000000
# 600909    352    3570.040000   19871.000000             0.0    24685.130000
#
#          newbalanceDest  isFlaggedFraud  type  nameDest  nameOrig
# 162757     159337.38000               0     1  183207.0     96649
# 476897     459896.08000               0     1  208691.0     48663
# 305893     254439.72000               0     1   59417.0    581824
# 11003           0.00000               0     3  292933.0    435630
# 920032      91922.70334               0     1   52464.0     17748
# ...                 ...             ...   ...       ...       ...
# 684283          0.00000               0     3  163726.5    426109
# 530816     159337.38000               0     1  102344.0    267358
# 1014827    159337.38000               0     1    8010.0    130708
# 980792          0.00000               0     1  229356.0    645224
# 600909      28255.17000               0     2  140420.0    211274
#
# [108364 rows x 10 columns]
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# import module
from sklearn.preprocessing import StandardScaler

# compute required values
scaler = StandardScaler()
model = scaler.fit(X_train_resampled_final)
X_train_resampled_final = model.transform(X_train_resampled_final)

# %%
# compute required values
scaler = StandardScaler()
model = scaler.fit(X_test)
X_test = model.transform(X_test)

# %% [markdown]
# ## Combining the power of the 2 pre-trained CNN
