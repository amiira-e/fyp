# %%
import numpy as np
import pandas as pd
df_sample=pd.read_csv(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\sample.csv")

# %%
df_sample = df_sample.reset_index(drop=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['type'])
label
df_sample.drop("type", axis=1, inplace=True)
df_sample["type"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['nameDest'])
label
df_sample.drop("nameDest", axis=1, inplace=True)
df_sample["nameDest"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['nameOrig'])
label
df_sample.drop("nameOrig", axis=1, inplace=True)
df_sample["nameOrig"] = label

# %%
import pandas as pd

# assuming df is your dataframe
new_order = ['step', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest', 'isFlaggedFraud', 'type', 'nameDest', 'nameOrig', 'isFraud']

# create a new dataframe with columns in the desired order
df_sample = df_sample.drop(columns=['isFraud']).assign(isFraud=df_sample['isFraud'])

# check that the new dataframe has columns in the desired order
print(df_sample.columns.tolist())
# Out:
# ['step', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest', 'isFlaggedFraud', 'type', 'nameDest', 'nameOrig', 'isFraud']

# %%
from sklearn.model_selection import train_test_split

X = df_sample.drop('isFraud', axis=1)
# Separate the target variable
y = df_sample['isFraud']

# Print class distribution before split
print(y.value_counts(normalize=True))

from sklearn.model_selection import train_test_split

# Assuming X contains your features and y contains your target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=2)

# Print class distribution after split
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# 0    0.998743
# 1    0.001257
# Name: isFraud, dtype: float64
# 0    0.998743
# 1    0.001257
# Name: isFraud, dtype: float64
# 0    0.998743
# 1    0.001257
# Name: isFraud, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

#Upsampling via SMOTE
smote = SMOTE(sampling_strategy=0.2, random_state=0)

#Downsample via RandomUnderSampler
rus = RandomUnderSampler(sampling_strategy=0.4, random_state=0)

#Application of the resampling methods
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
X_resampled, y_resampled = rus.fit_resample(X_resampled, y_resampled)

# %%
from imblearn.under_sampling import TomekLinks

#Resample using TomekLinks first
tomek_links = TomekLinks(sampling_strategy='majority')
X_train_resampled, y_train_resampled = tomek_links.fit_resample(X_resampled, y_resampled)

# %%
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours,OneSidedSelection
# resample the output of TomekLinks using EditedNearestNeighbours
enn = EditedNearestNeighbours(sampling_strategy='majority')
X_train_resampled_new, y_train_resampled_new = enn.fit_resample(X_train_resampled, y_train_resampled)

# %%
from imblearn.under_sampling import OneSidedSelection
# resample the output of EditedNearestNeighbours using One-Sided Selection
oss = OneSidedSelection(sampling_strategy='majority')
X_train_resampled_final, y_train_resampled_final = oss.fit_resample(X_train_resampled_new, y_train_resampled_new)

# %%
import random
import numpy as np
from scipy import stats

random.seed(0)
# Specify columns with outliers
cols_with_outliers = ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']

# Specify the number of bootstrapped samples to create per column
num_samples = 50

# Specify the right trimming proportions for each column
trim_props = {'amount': 0.01, 'oldbalanceOrg': 0.07, 'newbalanceOrig': 0.015, 'oldbalanceDest': 0.015, 'newbalanceDest': 0.01}

# Initialize empty dictionaries to store the trimmed means for each column
train_trimmed_means = {}

# Loop over the specified columns
for col_name in cols_with_outliers:
    
    # Check if the trimming proportion for this column is 0
    if trim_props[col_name] == 0:
        # If so, skip this column and move on to the next one
        continue
    
    # Initialize empty lists to store the bootstrapped samples and the trimmed means for the training set
    train_bootstrapped_samples = []
    train_trimmed_means_list = []
    
    # Loop over the number of desired samples
    for i in range(num_samples):
        # Randomly select indices from the column in the training set
        train_sample_indices = np.random.choice(X_train_resampled_final.index, size=len(X_train_resampled_final), replace=True)
        
        # Create a bootstrapped sample by indexing into the column with the selected indices for the training set
        train_sample = X_train_resampled_final.loc[train_sample_indices, col_name]
        
        # Append the bootstrapped samples to the list for the training set
        train_bootstrapped_samples.append(train_sample)
        
        # Calculate the right trimmed mean of the bootstrapped sample for the training set
        train_right_trimmed_mean = np.mean(train_sample[train_sample <= np.percentile(train_sample, 100*(1-trim_props[col_name]))])
        train_trimmed_means_list.append(train_right_trimmed_mean)
        
    # Calculate the mean of the right trimmed means for the training set and add it to the dictionary
    train_trimmed_means[col_name] = np.mean(train_trimmed_means_list)

    # Replace the outliers in the training set with the trimmed means
    X_train_resampled_final.loc[X_train_resampled_final[col_name] > np.percentile(X_train_resampled_final[col_name], 100*(1-trim_props[col_name])), col_name] = train_trimmed_means[col_name]
    
    # Replace the outliers in the test set with the trimmed means obtained from the train set
    test_outliers = X_test.loc[X_test[col_name] > np.percentile(X_test[col_name], 100*(1-trim_props[col_name])), col_name]
    X_test.loc[test_outliers.index, col_name] = train_trimmed_means[col_name]
    
# Print the trimmed means for each column separately for the training set
print("Train set trimmed means: ", train_trimmed_means)
# Out:
# Train set trimmed means:  {'amount': 610181.9861688031, 'oldbalanceOrg': 433601.35483023076, 'newbalanceOrig': 451519.7202575694, 'oldbalanceDest': 736620.928481994, 'newbalanceDest': 1096560.1212178157}

# %%
# import module
from sklearn.preprocessing import StandardScaler

# compute required values
scaler = StandardScaler()
model = scaler.fit(X_train_resampled_final)
X_train_resampled_final = model.transform(X_train_resampled_final)

model = scaler.fit(X_test)
X_test = model.transform(X_test)

# %% [markdown]
# #### However, since you are using the autoencoder as a feature extractor, you may want to use a loss function that encourages the model to learn a compact and meaningful representation of the input data.

# %% [markdown]
# ## Implemented autoencoder

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
# Set random seed for reproducibility
np.random.seed(42)

# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 4
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
test_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=15, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)
    
    # Calculate the MSE for the test set
    test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    test_mse.append(test_error)
    print(f"Test MSE: {test_error:.5f}")

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017928F033A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017928F033A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017928F91DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017928F91DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Test MSE: 0.60941
# Test MSE: 0.55949

# %%
from keras.utils import plot_model
plot_model(autoencoder, to_file='autoencoder_new.png', show_shapes=True)

# %%
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10)]              0
#
#  dense_2 (Dense)             (None, 4)                 44
#
#  dense_3 (Dense)             (None, 10)                50
#
# =================================================================
# Total params: 94
# Trainable params: 94
# Non-trainable params: 0
# _________________________________________________________________

# %%
import visualkeras
visualkeras.layered_view(autoencoder)
# Out:
# <PIL.Image.Image image mode=RGBA size=107x27>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
# Configure TensorBoard
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=1)

# Train the model with TensorBoard callback
autoencoder.fit(X_train_resampled_final, X_train_resampled_final,
                epochs=2, batch_size=32,
                validation_data=(X_test, X_test),
                callbacks=[tensorboard_callback])
# Out:
# Epoch 1/2
# 12765/12765 [==============================] - 55s 4ms/step - loss: 0.6434 - val_loss: 0.5730
# Epoch 2/2
# 12765/12765 [==============================] - 53s 4ms/step - loss: 0.6414 - val_loss: 0.5742
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# Traceback (most recent call last):
#   File "C:\Users\23059\anaconda3\envs\test2\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\23059\anaconda3\envs\test2\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\23059\anaconda3\envs\test2\Scripts\tensorboard.exe\__main__.py", line 4, in <module>
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorboard\main.py", line 40, in <module>
#     from tensorboard import default
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorboard\default.py", line 39, in <module>
#     from tensorboard.plugins.beholder import beholder_plugin_loader
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorboard\plugins\beholder\__init__.py", line 22, in <module>
#     from tensorboard.plugins.beholder.beholder import Beholder
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorboard\plugins\beholder\beholder.py", line 199, in <module>
#     class BeholderHook(tf.estimator.SessionRunHook):
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorflow\python\util\lazy_loader.py", line 58, in __getattr__
#     module = self._load()
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorflow\python\util\lazy_loader.py", line 41, in _load
#     module = importlib.import_module(self.__name__)
#   File "C:\Users\23059\anaconda3\envs\test2\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorflow_estimator\__init__.py", line 10, in <module>
#     from tensorflow_estimator._api.v1 import estimator
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorflow_estimator\_api\v1\estimator\__init__.py", line 10, in <module>
#     from tensorflow_estimator._api.v1.estimator import experimental
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorflow_estimator\_api\v1\estimator\experimental\__init__.py", line 10, in <module>
#     from tensorflow_estimator.python.estimator.canned.dnn import dnn_logit_fn_builder
#   File "C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py", line 23, in <module>
#     from tensorflow.python.feature_column import dense_features
# ImportError: cannot import name 'dense_features' from 'tensorflow.python.feature_column' (C:\Users\23059\anaconda3\envs\test2\lib\site-packages\tensorflow\python\feature_column\__init__.py)

# %%
# Launch TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir=./logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 14452.

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
# Set random seed for reproducibility
np.random.seed(42)

# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 50
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
test_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=15, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)
    
    # Calculate the MSE for the test set
    test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    test_mse.append(test_error)
    print(f"Test MSE: {test_error:.5f}")

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017930719558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017930719558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000179314DF828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000179314DF828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Test MSE: 0.53035
# Test MSE: 0.52678

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
# Set random seed for reproducibility
np.random.seed(42)

# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 25
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
test_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=15, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)
    
    # Calculate the MSE for the test set
    test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    test_mse.append(test_error)
    print(f"Test MSE: {test_error:.5f}")

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017934B58678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017934B58678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017931489798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017931489798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Test MSE: 0.55035
# Test MSE: 0.52690

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
# Set random seed for reproducibility
np.random.seed(42)

# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 30
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00099)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
test_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=15, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)
    
    # Calculate the MSE for the test set
    test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    test_mse.append(test_error)
    print(f"Test MSE: {test_error:.5f}")

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017933567EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017933567EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000179336F8948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000179336F8948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Test MSE: 0.52836
# Test MSE: 0.52870

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
# Set random seed for reproducibility
np.random.seed(42)

# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 30
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00099)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
test_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=20, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)
    
    # Calculate the MSE for the test set
    test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    test_mse.append(test_error)
    print(f"Test MSE: {test_error:.5f}")

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017933637EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017933637EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001792C19A438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001792C19A438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Test MSE: 0.52269
# Test MSE: 0.52221

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 30
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate
#opt = Adam(lr= 0.00874103303583597)
opt = Adam(lr= 0.00874103303583597)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# # plot the distribution of reconstruction errors
# plt.hist(recon_errors, bins=5)
# plt.xlabel('Reconstruction Error')
# plt.ylabel('Frequency')
# plt.title('Distribution of Reconstruction Errors')
# plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017931422AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017931422AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001793CD7B4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001793CD7B4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 40
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=15, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# plot the distribution of reconstruction errors
plt.hist(recon_errors, bins=5)
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.title('Distribution of Reconstruction Errors')
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017934B62708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000017934B62708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017934B3B558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017934B3B558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
#FOR THE CODE JUST ABOVE

test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
test_mse.append(test_error)
print(f"Test MSE: {test_error:.5f}")
# Out:
# Test MSE: 0.56158

# %% [markdown]
# ## Chosen

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 40
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=5, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# plot the distribution of reconstruction errors
plt.hist(recon_errors, bins=5)
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.title('Distribution of Reconstruction Errors')
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000179293134C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000179293134C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017929147C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000017929147C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
# Set random seed for reproducibility
np.random.seed(42)

# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 30
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
test_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)
    
    # Calculate the MSE for the test set
    test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    test_mse.append(test_error)
    print(f"Test MSE: {test_error:.5f}")

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01144C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01144C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA73A3C798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA73A3C798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Test MSE: 0.50626
# Test MSE: 0.50771

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
# Set random seed for reproducibility
np.random.seed(42)

# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 40
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
test_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=5, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)
    
    # Calculate the MSE for the test set
    test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    test_mse.append(test_error)
    print(f"Test MSE: {test_error:.5f}")

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01001EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01001EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0102D678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0102D678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Test MSE: 0.70105
# Test MSE: 0.67476

# %%
#FOR THE CODE JUST ABOVE

test_error = autoencoder.evaluate(X_test, X_test, verbose=0)
test_mse.append(test_error)
print(f"Test MSE: {test_error:.5f}")
# Out:
# Test MSE: 0.53659

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 40
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=5, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# plot the distribution of reconstruction errors
plt.hist(recon_errors, bins=5)
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.title('Distribution of Reconstruction Errors')
plt.show()
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001792BBF9CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001792BBF9CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6348/6383 [============================>.] - ETA: 0s - loss: 0.9589WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001792C08B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001792C08B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6383/6383 [==============================] - 16s 2ms/step - loss: 0.9574 - val_loss: 0.7055
# Epoch 2/5
# 6383/6383 [==============================] - 15s 2ms/step - loss: 0.8739 - val_loss: 0.7009
# Epoch 3/5
# 6383/6383 [==============================] - 15s 2ms/step - loss: 0.8579 - val_loss: 0.6769
# Epoch 4/5
# 6383/6383 [==============================] - 15s 2ms/step - loss: 0.8506 - val_loss: 0.6712
# Epoch 5/5
# 6383/6383 [==============================] - 16s 2ms/step - loss: 0.8464 - val_loss: 0.6666
# Epoch 1/5
# 6383/6383 [==============================] - 16s 2ms/step - loss: 0.6628 - val_loss: 0.9219
# Epoch 2/5
# 6383/6383 [==============================] - 15s 2ms/step - loss: 0.6609 - val_loss: 0.9207
# Epoch 3/5
# 6383/6383 [==============================] - 16s 2ms/step - loss: 0.6596 - val_loss: 0.9204
# Epoch 4/5
# 6383/6383 [==============================] - 15s 2ms/step - loss: 0.6138 - val_loss: 0.9048
# Epoch 5/5
# 6383/6383 [==============================] - 15s 2ms/step - loss: 0.5787 - val_loss: 0.8834

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 10
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=128, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA00071EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA00071EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1606/1620 [============================>.] - ETA: 0s - loss: 1.0724WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0006E5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0006E5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1620/1620 [==============================] - 5s 3ms/step - loss: 1.0724 - val_loss: 0.6502
# Epoch 2/10
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.8679 - val_loss: 0.5890
# Epoch 3/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.8336 - val_loss: 0.5645
# Epoch 4/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.8150 - val_loss: 0.5488
# Epoch 5/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.8030 - val_loss: 0.5383
# Epoch 6/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7945 - val_loss: 0.5306
# Epoch 7/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7880 - val_loss: 0.5247
# Epoch 8/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7829 - val_loss: 0.5201
# Epoch 9/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7789 - val_loss: 0.5167
# Epoch 10/10
# 1620/1620 [==============================] - 3s 2ms/step - loss: 0.7756 - val_loss: 0.5130
# Epoch 1/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.5063 - val_loss: 0.8472
# Epoch 2/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.5027 - val_loss: 0.8461
# Epoch 3/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.5002 - val_loss: 0.8478
# Epoch 4/10
# 1620/1620 [==============================] - 3s 2ms/step - loss: 0.4983 - val_loss: 0.8487
# Epoch 5/10
# 1620/1620 [==============================] - 3s 2ms/step - loss: 0.4968 - val_loss: 0.8496
# Epoch 6/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4955 - val_loss: 0.8505
# Epoch 7/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4943 - val_loss: 0.8508
# Epoch 8/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4933 - val_loss: 0.8521
# Epoch 9/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4924 - val_loss: 0.8535
# Epoch 10/10
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4916 - val_loss: 0.8552

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 17
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=8)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=64, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# # plot the distribution of reconstruction errors
# plt.hist(recon_errors, bins=2)
# plt.xlabel('Reconstruction Error')
# plt.ylabel('Frequency')
# plt.title('Distribution of Reconstruction Errors')
# plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA0006E948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA0006E948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3226/3240 [============================>.] - ETA: 0s - loss: 0.9739WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0021D438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0021D438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.9759 - val_loss: 0.5882
# Epoch 2/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.8241 - val_loss: 0.5437
# Epoch 3/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.7972 - val_loss: 0.5256
# Epoch 4/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7832 - val_loss: 0.5145
# Epoch 5/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.7744 - val_loss: 0.5071
# Epoch 6/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7689 - val_loss: 0.5028
# Epoch 7/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.7647 - val_loss: 0.4987
# Epoch 8/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7614 - val_loss: 0.4959
# Epoch 9/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.7590 - val_loss: 0.4937
# Epoch 10/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7569 - val_loss: 0.4918
# Epoch 1/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.4898 - val_loss: 0.7687
# Epoch 2/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.4883 - val_loss: 0.7683
# Epoch 3/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.4872 - val_loss: 0.7730
# Epoch 4/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.4863 - val_loss: 0.7701
# Epoch 5/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.4855 - val_loss: 0.7677
# Epoch 6/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.4848 - val_loss: 0.7687
# Epoch 7/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.4843 - val_loss: 0.7655
# Epoch 8/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.4837 - val_loss: 0.7666
# Epoch 9/10
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.4833 - val_loss: 0.7704
# Epoch 10/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.4829 - val_loss: 0.7704

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 17
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []

# Loop over each fold
for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=8)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=64, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Print the MSE of training and validation sets for each epoch
    for i in range(len(history.history['loss'])):
        print(f"Fold {fold+1}, Epoch {i+1}, Training MSE: {history.history['loss'][i]}, Validation MSE: {history.history['val_loss'][i]}")
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA00244F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA00244F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3208/3240 [============================>.] - ETA: 0s - loss: 0.9807WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA01651DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA01651DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.9776 - val_loss: 0.6309
# Epoch 2/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.8316 - val_loss: 0.5471
# Epoch 3/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.7979 - val_loss: 0.5268
# Epoch 4/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.7835 - val_loss: 0.5158
# Epoch 5/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.7751 - val_loss: 0.5087
# Epoch 6/10
# 2794/3240 [========================>.....] - ETA: 0s - loss: 0.7833
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13348\4251011772.py in <module>
#      47
#      48     # Fit the autoencoder on the training set for the current fold
# ---> 49     history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=64, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
#      50
#      51     # Print the MSE of training and validation sets for each epoch
#
# ~\anaconda3\envs\test2\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\test2\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~\anaconda3\envs\test2\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\test2\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\test2\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\test2\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#     134     return concrete_function._call_flat(
# --> 135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#     137   @property
#
# ~\anaconda3\envs\test2\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~\anaconda3\envs\test2\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     381               inputs=args,
#     382               attrs=attrs,
# --> 383               ctx=ctx)
#     384         else:
#     385           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\test2\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51     ctx.ensure_initialized()
#      52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#      55     if name is not None:
#
# KeyboardInterrupt:

# %%
mean_train_mse_avg = np.mean(mean_train_mse)
print("Mean Train MSE (Average):", mean_train_mse_avg)

# %%
mse = autoencoder.evaluate(X_test, X_test)
print('Mean squared error on test data:', mse)

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 20
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# # plot the distribution of reconstruction errors
# plt.hist(recon_errors, bins=3)
# plt.xlabel('Reconstruction Error')
# plt.ylabel('Frequency')
# plt.title('Distribution of Reconstruction Errors')
# plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA02FDF558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA02FDF558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6454/6479 [============================>.] - ETA: 0s - loss: 0.9536WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0101FE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0101FE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.9558 - val_loss: 0.6555
# Epoch 2/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8629 - val_loss: 0.6371
# Epoch 3/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.8477 - val_loss: 0.6263
# Epoch 4/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.8401 - val_loss: 0.6188
# Epoch 5/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.8355 - val_loss: 0.6253
# Epoch 6/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8326 - val_loss: 0.6163
# Epoch 7/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8301 - val_loss: 0.6128
# Epoch 8/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8285 - val_loss: 0.6130
# Epoch 9/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8268 - val_loss: 0.6091
# Epoch 10/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8263 - val_loss: 0.6095
# Epoch 1/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.6049 - val_loss: 0.9047
# Epoch 2/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.6036 - val_loss: 0.9052
# Epoch 3/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.6029 - val_loss: 0.9054
# Epoch 4/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.6024 - val_loss: 0.9047
# Epoch 5/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.6020 - val_loss: 0.9055
# Epoch 6/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.6016 - val_loss: 0.9050
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\numpy\core\_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 32
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01F35DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01F35DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6449/6479 [============================>.] - ETA: 0s - loss: 0.9616WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA738DE798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA738DE798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 19s 3ms/step - loss: 0.9637 - val_loss: 0.6757
# Epoch 2/10
# 6479/6479 [==============================] - 19s 3ms/step - loss: 0.8656 - val_loss: 0.6351
# Epoch 3/10
# 6479/6479 [==============================] - 20s 3ms/step - loss: 0.8500 - val_loss: 0.6308
# Epoch 4/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.8419 - val_loss: 0.6197
# Epoch 5/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8369 - val_loss: 0.6219
# Epoch 6/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8342 - val_loss: 0.6265
# Epoch 7/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8314 - val_loss: 0.6112
# Epoch 8/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8295 - val_loss: 0.6114
# Epoch 9/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8288 - val_loss: 0.6165
# Epoch 10/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8272 - val_loss: 0.6094
# Epoch 1/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.6050 - val_loss: 0.9050
# Epoch 2/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.6038 - val_loss: 0.9055
# Epoch 3/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.6030 - val_loss: 0.9048
# Epoch 4/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.6024 - val_loss: 0.9053
# Epoch 5/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.6019 - val_loss: 0.9067
# Epoch 6/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.6015 - val_loss: 0.9047
# Epoch 7/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.6011 - val_loss: 0.9043
# Epoch 8/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.6008 - val_loss: 0.9052
# Epoch 9/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.6005 - val_loss: 0.9054
# Epoch 10/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.6003 - val_loss: 0.9031

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 18
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.02))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=15, batch_size=32, verbose=0, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# # plot the distribution of reconstruction errors
# plt.hist(recon_errors, bins=5)
# plt.xlabel('Reconstruction Error')
# plt.ylabel('Frequency')
# plt.title('Distribution of Reconstruction Errors')
# plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01628048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01628048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0111DD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0111DD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 9
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA013C0318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA013C0318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6451/6479 [============================>.] - ETA: 0s - loss: 0.9643WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA03002AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA03002AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.9665 - val_loss: 0.7027
# Epoch 2/10
# 6479/6479 [==============================] - 12s 2ms/step - loss: 0.8759 - val_loss: 0.6799
# Epoch 3/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8607 - val_loss: 0.6697
# Epoch 4/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8533 - val_loss: 0.6647
# Epoch 5/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8492 - val_loss: 0.6624
# Epoch 6/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8460 - val_loss: 0.6612
# Epoch 7/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8443 - val_loss: 0.6584
# Epoch 8/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8427 - val_loss: 0.6561
# Epoch 9/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8414 - val_loss: 0.6553
# Epoch 10/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8409 - val_loss: 0.6539
# Epoch 1/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.6520 - val_loss: 0.9206
# Epoch 2/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.6512 - val_loss: 0.9206
# Epoch 3/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.6506 - val_loss: 0.9209
# Epoch 4/10
# 6479/6479 [==============================] - 12s 2ms/step - loss: 0.6501 - val_loss: 0.9198
# Epoch 5/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.6497 - val_loss: 0.9186
# Epoch 6/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.6494 - val_loss: 0.9187
# Epoch 7/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.6374 - val_loss: 0.9142
# Epoch 8/10
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.5937 - val_loss: 0.8997
# Epoch 9/10
# 6479/6479 [==============================] - 12s 2ms/step - loss: 0.5882 - val_loss: 0.8965
# Epoch 10/10
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.5863 - val_loss: 0.8963

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 9
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []


# Loop over each fold
for train_index, val_index in kf.split(X_train_resampled_final):
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=14, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold),callbacks=[early_stopping])
    
    # Append the MSE of training and validation sets for the current fold to the lists
    train_mse.append(history.history['loss'])
    val_mse.append(history.history['val_loss'])
    
    # compute the reconstruction error for the test data
    recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
    recon_errors.append(recon_error)

# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
# mean_train_mse = np.mean(train_mse, axis=0)
# std_train_mse = np.std(train_mse, axis=0)
# mean_val_mse = np.mean(val_mse, axis=0)
# std_val_mse = np.std(val_mse, axis=0)
# Calculate the mean and standard deviation of MSE for training and validation sets across all folds
mean_train_mse = np.mean(train_mse, axis=0)
#std_train_mse = np.std(np.array(train_mse), axis=0)
std_train_mse = np.std(np.concatenate(train_mse), axis=0)

mean_val_mse = np.mean(val_mse, axis=0)
#std_val_mse = np.std(np.array(val_mse), axis=0)
std_val_mse = np.std(np.concatenate(val_mse), axis=0)


# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Epoch 1/14
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA739048B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA739048B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6463/6479 [============================>.] - ETA: 0s - loss: 0.9520WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA02FC7318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA02FC7318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.9515 - val_loss: 0.6662
# Epoch 2/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8602 - val_loss: 0.6312
# Epoch 3/14
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8424 - val_loss: 0.6205
# Epoch 4/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8340 - val_loss: 0.6148
# Epoch 5/14
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8294 - val_loss: 0.6094
# Epoch 6/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8264 - val_loss: 0.6062
# Epoch 7/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8238 - val_loss: 0.6051
# Epoch 8/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8223 - val_loss: 0.6042
# Epoch 9/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8208 - val_loss: 0.6011
# Epoch 10/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8202 - val_loss: 0.6017
# Epoch 11/14
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8195 - val_loss: 0.6017
# Epoch 12/14
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8185 - val_loss: 0.5987
# Epoch 13/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.8181 - val_loss: 0.5994
# Epoch 14/14
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.8175 - val_loss: 0.6041
# Epoch 1/14
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.5978 - val_loss: 0.8228
# Epoch 2/14
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.5969 - val_loss: 0.8241
# Epoch 3/14
# 6479/6479 [==============================] - 13s 2ms/step - loss: 0.5966 - val_loss: 0.8233
# Epoch 4/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.5964 - val_loss: 0.8282
# Epoch 5/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.5961 - val_loss: 0.8356
# Epoch 6/14
# 6479/6479 [==============================] - 14s 2ms/step - loss: 0.5959 - val_loss: 0.8284

# %% [markdown]
# ## Visual representation

# %%
# Define the encoder model
encoder = Model(inputs=input_layer, outputs=hidden_layer)

# Get the encoded representations for the training set
encoded_train = encoder.predict(X_train_resampled_final)

# Plot the encoded representations
plt.scatter(encoded_train[:, 0], encoded_train[:, 1], c=y_train_resampled_final)
plt.colorbar()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001FA00F00DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001FA00F00DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 12957/12957 [==============================] - 16s 1ms/step

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 17
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []
test_mse = []

for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    # Print the fold number
    print(f"\nFold {fold+1}")
    print("------------------------------------")
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=8)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=64, verbose=1, validation_data=(X_val_fold, X_val_fold), callbacks=[early_stopping])
    
    for i in range(len(history.history['loss'])):
        train_mse_epoch = round(history.history['loss'][i], 5)
        val_mse_epoch = round(history.history['val_loss'][i], 5)
        print(f"Epoch {i+1}, Train MSE: {train_mse_epoch}, Validation MSE: {val_mse_epoch}")
        train_mse.append(train_mse_epoch)
        val_mse.append(val_mse_epoch)

    # Append the mean MSE of training and validation sets for the current fold to the lists
    train_mse.append(np.mean(history.history['loss']))
    val_mse.append(np.mean(history.history['val_loss']))

    
#     # compute the reconstruction error for the test data
#     recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
#     recon_errors.append(recon_error)

# Print the final mean and standard deviation of MSE for training and validation sets across all folds
print("\nFinal results:")
print(f"Mean Train MSE: {np.mean(train_mse):.5f}")
print(f"Mean Validation MSE: {np.mean(val_mse):.5f}")

# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Fold 1
# ------------------------------------
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01F5B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01F5B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3232/3240 [============================>.] - ETA: 0s - loss: 0.9698WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA6BC511F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA6BC511F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3240/3240 [==============================] - 24s 7ms/step - loss: 0.9724 - val_loss: 0.5866
# Epoch 2/10
# 3240/3240 [==============================] - 21s 6ms/step - loss: 0.8204 - val_loss: 0.5457
# Epoch 3/10
# 3240/3240 [==============================] - 23s 7ms/step - loss: 0.7941 - val_loss: 0.5272
# Epoch 4/10
# 3240/3240 [==============================] - 20s 6ms/step - loss: 0.7793 - val_loss: 0.5152
# Epoch 5/10
# 3240/3240 [==============================] - 22s 7ms/step - loss: 0.7701 - val_loss: 0.5088
# Epoch 6/10
# 3240/3240 [==============================] - 22s 7ms/step - loss: 0.7644 - val_loss: 0.5033
# Epoch 7/10
# 3240/3240 [==============================] - 21s 7ms/step - loss: 0.7602 - val_loss: 0.5000
# Epoch 8/10
# 3240/3240 [==============================] - 20s 6ms/step - loss: 0.7569 - val_loss: 0.4969
# Epoch 9/10
# 3240/3240 [==============================] - 24s 7ms/step - loss: 0.7543 - val_loss: 0.4947
# Epoch 10/10
# 3240/3240 [==============================] - 20s 6ms/step - loss: 0.7522 - val_loss: 0.4930
# Epoch 1, Train MSE: 0.97243, Validation MSE: 0.58657
# Epoch 2, Train MSE: 0.82043, Validation MSE: 0.5457
# Epoch 3, Train MSE: 0.79409, Validation MSE: 0.52719
# Epoch 4, Train MSE: 0.77933, Validation MSE: 0.51516
# Epoch 5, Train MSE: 0.77013, Validation MSE: 0.50875
# Epoch 6, Train MSE: 0.76436, Validation MSE: 0.50335
# Epoch 7, Train MSE: 0.76021, Validation MSE: 0.49998
# Epoch 8, Train MSE: 0.75687, Validation MSE: 0.49695
# Epoch 9, Train MSE: 0.75435, Validation MSE: 0.49472
# Epoch 10, Train MSE: 0.75219, Validation MSE: 0.49301
#
# Fold 2
# ------------------------------------
# Epoch 1/10
# 3240/3240 [==============================] - 26s 8ms/step - loss: 0.4903 - val_loss: 0.7618
# Epoch 2/10
# 3240/3240 [==============================] - 23s 7ms/step - loss: 0.4885 - val_loss: 0.7598
# Epoch 3/10
# 3240/3240 [==============================] - 23s 7ms/step - loss: 0.4872 - val_loss: 0.7591
# Epoch 4/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.4861 - val_loss: 0.7597
# Epoch 5/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.4852 - val_loss: 0.7588
# Epoch 6/10
# 3240/3240 [==============================] - 10s 3ms/step - loss: 0.4845 - val_loss: 0.7596
# Epoch 7/10
# 3240/3240 [==============================] - 10s 3ms/step - loss: 0.4838 - val_loss: 0.7593
# Epoch 8/10
# 3240/3240 [==============================] - 10s 3ms/step - loss: 0.4833 - val_loss: 0.7608
# Epoch 9/10
# 3240/3240 [==============================] - 10s 3ms/step - loss: 0.4828 - val_loss: 0.7616
# Epoch 10/10
# 3240/3240 [==============================] - 13s 4ms/step - loss: 0.4823 - val_loss: 0.7613
# Epoch 1, Train MSE: 0.49031, Validation MSE: 0.76183
# Epoch 2, Train MSE: 0.48854, Validation MSE: 0.75982
# Epoch 3, Train MSE: 0.4872, Validation MSE: 0.75911
# Epoch 4, Train MSE: 0.48612, Validation MSE: 0.75975
# Epoch 5, Train MSE: 0.48523, Validation MSE: 0.75879
# Epoch 6, Train MSE: 0.48449, Validation MSE: 0.75957
# Epoch 7, Train MSE: 0.48384, Validation MSE: 0.75932
# Epoch 8, Train MSE: 0.48327, Validation MSE: 0.76082
# Epoch 9, Train MSE: 0.48276, Validation MSE: 0.76156
# Epoch 10, Train MSE: 0.48231, Validation MSE: 0.76131
#
# Final results:
# Mean Train MSE: 0.63892
# Mean Validation MSE: 0.63866

# %%
mse = autoencoder.evaluate(X_test, X_test)
print('Mean squared error on test data:', mse)
# Out:
# 2188/2188 [==============================] - 3s 1ms/step - loss: 0.5310
# Mean squared error on test data: 0.5309798717498779

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 28
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.0991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.001)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []
test_mse = []

for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    # Print the fold number
    print(f"\nFold {fold+1}")
    print("------------------------------------")
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=12, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold), callbacks=[early_stopping])
    
    for i in range(len(history.history['loss'])):
        train_mse_epoch = round(history.history['loss'][i], 5)
        val_mse_epoch = round(history.history['val_loss'][i], 5)
        print(f"Epoch {i+1}, Train MSE: {train_mse_epoch}, Validation MSE: {val_mse_epoch}")
        train_mse.append(train_mse_epoch)
        val_mse.append(val_mse_epoch)

    # Append the mean MSE of training and validation sets for the current fold to the lists
    train_mse.append(np.mean(history.history['loss']))
    val_mse.append(np.mean(history.history['val_loss']))

    
#     # compute the reconstruction error for the test data
#     recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
#     recon_errors.append(recon_error)

# Print the final mean and standard deviation of MSE for training and validation sets across all folds
print("\nFinal results:")
print(f"Mean Train MSE: {np.mean(train_mse):.5f}")
print(f"Mean Validation MSE: {np.mean(val_mse):.5f}")

# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Fold 1
# ------------------------------------
# Epoch 1/12
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA73A64798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA73A64798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6462/6479 [============================>.] - ETA: 0s - loss: 1.2763WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA00A1BE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA00A1BE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 17s 3ms/step - loss: 1.2788 - val_loss: 0.8855
# Epoch 2/12
# 6479/6479 [==============================] - 17s 3ms/step - loss: 1.1678 - val_loss: 0.8707
# Epoch 3/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.1677 - val_loss: 0.8781
# Epoch 4/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.1677 - val_loss: 0.8818
# Epoch 5/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.1678 - val_loss: 0.8783
# Epoch 6/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.1664 - val_loss: 0.8872
# Epoch 7/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.1075 - val_loss: 0.8768
# Epoch 8/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.0841 - val_loss: 0.8568
# Epoch 9/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.0741 - val_loss: 0.8572
# Epoch 10/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.0679 - val_loss: 0.8510
# Epoch 11/12
# 6479/6479 [==============================] - 17s 3ms/step - loss: 1.0632 - val_loss: 0.8479
# Epoch 12/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 1.0593 - val_loss: 0.8431
# Epoch 1, Train MSE: 1.2788, Validation MSE: 0.8855
# Epoch 2, Train MSE: 1.16776, Validation MSE: 0.8707
# Epoch 3, Train MSE: 1.1677, Validation MSE: 0.8781
# Epoch 4, Train MSE: 1.16771, Validation MSE: 0.88182
# Epoch 5, Train MSE: 1.16776, Validation MSE: 0.87832
# Epoch 6, Train MSE: 1.16637, Validation MSE: 0.88724
# Epoch 7, Train MSE: 1.10749, Validation MSE: 0.87681
# Epoch 8, Train MSE: 1.08412, Validation MSE: 0.8568
# Epoch 9, Train MSE: 1.0741, Validation MSE: 0.85725
# Epoch 10, Train MSE: 1.06795, Validation MSE: 0.85103
# Epoch 11, Train MSE: 1.06324, Validation MSE: 0.84791
# Epoch 12, Train MSE: 1.05929, Validation MSE: 0.84307
#
# Fold 2
# ------------------------------------
# Epoch 1/12
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.8051 - val_loss: 1.1492
# Epoch 2/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8036 - val_loss: 1.1490
# Epoch 3/12
# 6479/6479 [==============================] - 16s 3ms/step - loss: 0.8029 - val_loss: 1.1478
# Epoch 4/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8023 - val_loss: 1.1481
# Epoch 5/12
# 6479/6479 [==============================] - 16s 3ms/step - loss: 0.8018 - val_loss: 1.1491
# Epoch 6/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8013 - val_loss: 1.1470
# Epoch 7/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8009 - val_loss: 1.1446
# Epoch 8/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8006 - val_loss: 1.1461
# Epoch 9/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8003 - val_loss: 1.1441
# Epoch 10/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8000 - val_loss: 1.1441
# Epoch 11/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.7997 - val_loss: 1.1436
# Epoch 12/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7994 - val_loss: 1.1449
# Epoch 1, Train MSE: 0.80508, Validation MSE: 1.14924
# Epoch 2, Train MSE: 0.80359, Validation MSE: 1.14904
# Epoch 3, Train MSE: 0.80289, Validation MSE: 1.14776
# Epoch 4, Train MSE: 0.80229, Validation MSE: 1.14809
# Epoch 5, Train MSE: 0.80179, Validation MSE: 1.1491
# Epoch 6, Train MSE: 0.80133, Validation MSE: 1.14704
# Epoch 7, Train MSE: 0.80093, Validation MSE: 1.14463
# Epoch 8, Train MSE: 0.8006, Validation MSE: 1.1461
# Epoch 9, Train MSE: 0.80026, Validation MSE: 1.14414
# Epoch 10, Train MSE: 0.79998, Validation MSE: 1.14415
# Epoch 11, Train MSE: 0.79969, Validation MSE: 1.14362
# Epoch 12, Train MSE: 0.79944, Validation MSE: 1.14493
#
# Final results:
# Mean Train MSE: 0.96626
# Mean Validation MSE: 1.00718

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 70
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.00991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []
test_mse = []

for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    # Print the fold number
    print(f"\nFold {fold+1}")
    print("------------------------------------")
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=12, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold), callbacks=[early_stopping])
    
    for i in range(len(history.history['loss'])):
        train_mse_epoch = round(history.history['loss'][i], 5)
        val_mse_epoch = round(history.history['val_loss'][i], 5)
        print(f"Epoch {i+1}, Train MSE: {train_mse_epoch}, Validation MSE: {val_mse_epoch}")
        train_mse.append(train_mse_epoch)
        val_mse.append(val_mse_epoch)

    # Append the mean MSE of training and validation sets for the current fold to the lists
    train_mse.append(np.mean(history.history['loss']))
    val_mse.append(np.mean(history.history['val_loss']))

# Print the final mean and standard deviation of MSE for training and validation sets across all folds
print("\nFinal results:")
print(f"Mean Train MSE: {np.mean(train_mse):.5f}")
print(f"Mean Validation MSE: {np.mean(val_mse):.5f}")

# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Fold 1
# ------------------------------------
# Epoch 1/12
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01544048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01544048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6460/6479 [============================>.] - ETA: 0s - loss: 0.9281WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0154A5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0154A5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.9272 - val_loss: 0.5865
# Epoch 2/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8246 - val_loss: 0.5493
# Epoch 3/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7876 - val_loss: 0.5160
# Epoch 4/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7738 - val_loss: 0.5063
# Epoch 5/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7666 - val_loss: 0.5029
# Epoch 6/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7628 - val_loss: 0.4971
# Epoch 7/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7605 - val_loss: 0.4951
# Epoch 8/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7585 - val_loss: 0.4928
# Epoch 9/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.7568 - val_loss: 0.4913
# Epoch 10/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.7557 - val_loss: 0.4908
# Epoch 11/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.7547 - val_loss: 0.4897
# Epoch 12/12
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.7535 - val_loss: 0.4896
# Epoch 1, Train MSE: 0.92716, Validation MSE: 0.58649
# Epoch 2, Train MSE: 0.82458, Validation MSE: 0.54926
# Epoch 3, Train MSE: 0.78756, Validation MSE: 0.51604
# Epoch 4, Train MSE: 0.77381, Validation MSE: 0.50626
# Epoch 5, Train MSE: 0.76664, Validation MSE: 0.5029
# Epoch 6, Train MSE: 0.76284, Validation MSE: 0.49712
# Epoch 7, Train MSE: 0.7605, Validation MSE: 0.49515
# Epoch 8, Train MSE: 0.75847, Validation MSE: 0.4928
# Epoch 9, Train MSE: 0.75684, Validation MSE: 0.49129
# Epoch 10, Train MSE: 0.75567, Validation MSE: 0.49077
# Epoch 11, Train MSE: 0.75466, Validation MSE: 0.48967
# Epoch 12, Train MSE: 0.7535, Validation MSE: 0.48965
#
# Fold 2
# ------------------------------------
# Epoch 1/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4871 - val_loss: 0.7615
# Epoch 2/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4862 - val_loss: 0.7638
# Epoch 3/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4855 - val_loss: 0.7637
# Epoch 4/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4849 - val_loss: 0.7632
# Epoch 5/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4844 - val_loss: 0.7632
# Epoch 6/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4840 - val_loss: 0.7661
# Epoch 7/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4836 - val_loss: 0.7640
# Epoch 8/12
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.4833 - val_loss: 0.7608
# Epoch 9/12
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.4830 - val_loss: 0.7636
# Epoch 10/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4827 - val_loss: 0.7629
# Epoch 11/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4824 - val_loss: 0.7619
# Epoch 12/12
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.4822 - val_loss: 0.7643
# Epoch 1, Train MSE: 0.48708, Validation MSE: 0.76153
# Epoch 2, Train MSE: 0.48616, Validation MSE: 0.76375
# Epoch 3, Train MSE: 0.48546, Validation MSE: 0.76373
# Epoch 4, Train MSE: 0.48489, Validation MSE: 0.7632
# Epoch 5, Train MSE: 0.48441, Validation MSE: 0.76318
# Epoch 6, Train MSE: 0.48399, Validation MSE: 0.76609
# Epoch 7, Train MSE: 0.48361, Validation MSE: 0.76403
# Epoch 8, Train MSE: 0.48327, Validation MSE: 0.76075
# Epoch 9, Train MSE: 0.48296, Validation MSE: 0.76358
# Epoch 10, Train MSE: 0.48269, Validation MSE: 0.76294
# Epoch 11, Train MSE: 0.48243, Validation MSE: 0.7619
# Epoch 12, Train MSE: 0.48219, Validation MSE: 0.76427
#
# Final results:
# Mean Train MSE: 0.63297
# Mean Validation MSE: 0.63610

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 17
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.01991))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.00087)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []
test_mse = []

for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    # Print the fold number
    print(f"\nFold {fold+1}")
    print("------------------------------------")
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=8)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=64, verbose=1, validation_data=(X_val_fold, X_val_fold), callbacks=[early_stopping])
    
    for i in range(len(history.history['loss'])):
        train_mse_epoch = round(history.history['loss'][i], 5)
        val_mse_epoch = round(history.history['val_loss'][i], 5)
        print(f"Epoch {i+1}, Train MSE: {train_mse_epoch}, Validation MSE: {val_mse_epoch}")
        train_mse.append(train_mse_epoch)
        val_mse.append(val_mse_epoch)

    # Append the mean MSE of training and validation sets for the current fold to the lists
    train_mse.append(np.mean(history.history['loss']))
    val_mse.append(np.mean(history.history['val_loss']))

    
#     # compute the reconstruction error for the test data
#     recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
#     recon_errors.append(recon_error)

# Print the final mean and standard deviation of MSE for training and validation sets across all folds
print("\nFinal results:")
print(f"Mean Train MSE: {np.mean(train_mse):.5f}")
print(f"Mean Validation MSE: {np.mean(val_mse):.5f}")

# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Fold 1
# ------------------------------------
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01E9C1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA01E9C1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3239/3240 [============================>.] - ETA: 0s - loss: 1.0847WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA000A8EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA000A8EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3240/3240 [==============================] - 8s 2ms/step - loss: 1.0847 - val_loss: 0.7522
# Epoch 2/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.9180 - val_loss: 0.7173
# Epoch 3/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8928 - val_loss: 0.7010
# Epoch 4/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8798 - val_loss: 0.6894
# Epoch 5/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8681 - val_loss: 0.6490
# Epoch 6/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8530 - val_loss: 0.6296
# Epoch 7/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8441 - val_loss: 0.6223
# Epoch 8/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8390 - val_loss: 0.6183
# Epoch 9/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.8351 - val_loss: 0.6140
# Epoch 10/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.8319 - val_loss: 0.6116
# Epoch 1, Train MSE: 1.08472, Validation MSE: 0.75219
# Epoch 2, Train MSE: 0.91804, Validation MSE: 0.71728
# Epoch 3, Train MSE: 0.89284, Validation MSE: 0.70104
# Epoch 4, Train MSE: 0.87976, Validation MSE: 0.68944
# Epoch 5, Train MSE: 0.86815, Validation MSE: 0.64905
# Epoch 6, Train MSE: 0.85302, Validation MSE: 0.62963
# Epoch 7, Train MSE: 0.84411, Validation MSE: 0.62232
# Epoch 8, Train MSE: 0.83904, Validation MSE: 0.61825
# Epoch 9, Train MSE: 0.83506, Validation MSE: 0.61398
# Epoch 10, Train MSE: 0.83186, Validation MSE: 0.61165
#
# Fold 2
# ------------------------------------
# Epoch 1/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.6046 - val_loss: 0.9108
# Epoch 2/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.6019 - val_loss: 0.9090
# Epoch 3/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.6002 - val_loss: 0.9092
# Epoch 4/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.5989 - val_loss: 0.9085
# Epoch 5/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.5978 - val_loss: 0.9068
# Epoch 6/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.5968 - val_loss: 0.9059
# Epoch 7/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.5901 - val_loss: 0.8850
# Epoch 8/10
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.5628 - val_loss: 0.8768
# Epoch 9/10
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.5572 - val_loss: 0.8727
# Epoch 10/10
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.5541 - val_loss: 0.8702
# Epoch 1, Train MSE: 0.60464, Validation MSE: 0.91078
# Epoch 2, Train MSE: 0.60186, Validation MSE: 0.909
# Epoch 3, Train MSE: 0.60023, Validation MSE: 0.90917
# Epoch 4, Train MSE: 0.5989, Validation MSE: 0.90853
# Epoch 5, Train MSE: 0.59778, Validation MSE: 0.90678
# Epoch 6, Train MSE: 0.5968, Validation MSE: 0.90586
# Epoch 7, Train MSE: 0.59015, Validation MSE: 0.88495
# Epoch 8, Train MSE: 0.56283, Validation MSE: 0.87678
# Epoch 9, Train MSE: 0.55717, Validation MSE: 0.87268
# Epoch 10, Train MSE: 0.55411, Validation MSE: 0.87024
#
# Final results:
# Mean Train MSE: 0.73555
# Mean Validation MSE: 0.77798

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 45
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.01))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.001)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []
test_mse = []

for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    # Print the fold number
    print(f"\nFold {fold+1}")
    print("------------------------------------")
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=12, batch_size=128, verbose=1, validation_data=(X_val_fold, X_val_fold), callbacks=[early_stopping])
    
    for i in range(len(history.history['loss'])):
        train_mse_epoch = round(history.history['loss'][i], 5)
        val_mse_epoch = round(history.history['val_loss'][i], 5)
        print(f"Epoch {i+1}, Train MSE: {train_mse_epoch}, Validation MSE: {val_mse_epoch}")
        train_mse.append(train_mse_epoch)
        val_mse.append(val_mse_epoch)

    # Append the mean MSE of training and validation sets for the current fold to the lists
    train_mse.append(np.mean(history.history['loss']))
    val_mse.append(np.mean(history.history['val_loss']))

    
#     # compute the reconstruction error for the test data
#     recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
#     recon_errors.append(recon_error)

# Print the final mean and standard deviation of MSE for training and validation sets across all folds
print("\nFinal results:")
print(f"Mean Train MSE: {np.mean(train_mse):.5f}")
print(f"Mean Validation MSE: {np.mean(val_mse):.5f}")

# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Fold 1
# ------------------------------------
# Epoch 1/12
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA00AAFAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA00AAFAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1590/1620 [============================>.] - ETA: 0s - loss: 1.0454WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA03494828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA03494828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1620/1620 [==============================] - 4s 3ms/step - loss: 1.0428 - val_loss: 0.6556
# Epoch 2/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.8554 - val_loss: 0.5730
# Epoch 3/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.8185 - val_loss: 0.5504
# Epoch 4/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.8014 - val_loss: 0.5371
# Epoch 5/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.7903 - val_loss: 0.5284
# Epoch 6/12
# 1620/1620 [==============================] - 5s 3ms/step - loss: 0.7822 - val_loss: 0.5208
# Epoch 7/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7762 - val_loss: 0.5149
# Epoch 8/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7714 - val_loss: 0.5109
# Epoch 9/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.7674 - val_loss: 0.5077
# Epoch 10/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7643 - val_loss: 0.5044
# Epoch 11/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7615 - val_loss: 0.5019
# Epoch 12/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.7593 - val_loss: 0.4997
# Epoch 1, Train MSE: 1.04275, Validation MSE: 0.65562
# Epoch 2, Train MSE: 0.85536, Validation MSE: 0.573
# Epoch 3, Train MSE: 0.81845, Validation MSE: 0.5504
# Epoch 4, Train MSE: 0.80139, Validation MSE: 0.5371
# Epoch 5, Train MSE: 0.79028, Validation MSE: 0.52841
# Epoch 6, Train MSE: 0.78219, Validation MSE: 0.52083
# Epoch 7, Train MSE: 0.77617, Validation MSE: 0.51489
# Epoch 8, Train MSE: 0.77144, Validation MSE: 0.51093
# Epoch 9, Train MSE: 0.76737, Validation MSE: 0.50769
# Epoch 10, Train MSE: 0.76426, Validation MSE: 0.50443
# Epoch 11, Train MSE: 0.76149, Validation MSE: 0.50186
# Epoch 12, Train MSE: 0.75926, Validation MSE: 0.49973
#
# Fold 2
# ------------------------------------
# Epoch 1/12
# 1620/1620 [==============================] - 5s 3ms/step - loss: 0.4966 - val_loss: 0.7703
# Epoch 2/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.4945 - val_loss: 0.7717
# Epoch 3/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4929 - val_loss: 0.7712
# Epoch 4/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.4916 - val_loss: 0.7709
# Epoch 5/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.4904 - val_loss: 0.7698
# Epoch 6/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.4894 - val_loss: 0.7704
# Epoch 7/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.4886 - val_loss: 0.7748
# Epoch 8/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4878 - val_loss: 0.7702
# Epoch 9/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.4872 - val_loss: 0.7689
# Epoch 10/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4866 - val_loss: 0.7680
# Epoch 11/12
# 1620/1620 [==============================] - 4s 2ms/step - loss: 0.4860 - val_loss: 0.7700
# Epoch 12/12
# 1620/1620 [==============================] - 4s 3ms/step - loss: 0.4855 - val_loss: 0.7686
# Epoch 1, Train MSE: 0.49661, Validation MSE: 0.77032
# Epoch 2, Train MSE: 0.4945, Validation MSE: 0.77175
# Epoch 3, Train MSE: 0.4929, Validation MSE: 0.77119
# Epoch 4, Train MSE: 0.49156, Validation MSE: 0.77092
# Epoch 5, Train MSE: 0.49041, Validation MSE: 0.76982
# Epoch 6, Train MSE: 0.48944, Validation MSE: 0.77042
# Epoch 7, Train MSE: 0.48858, Validation MSE: 0.77476
# Epoch 8, Train MSE: 0.48783, Validation MSE: 0.7702
# Epoch 9, Train MSE: 0.48716, Validation MSE: 0.76888
# Epoch 10, Train MSE: 0.48656, Validation MSE: 0.76804
# Epoch 11, Train MSE: 0.48601, Validation MSE: 0.76995
# Epoch 12, Train MSE: 0.48552, Validation MSE: 0.76863
#
# Final results:
# Mean Train MSE: 0.64865
# Mean Validation MSE: 0.65207

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 46
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.03))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.001)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []
test_mse = []

for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    # Print the fold number
    print(f"\nFold {fold+1}")
    print("------------------------------------")
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=10, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold), callbacks=[early_stopping])
    
    for i in range(len(history.history['loss'])):
        train_mse_epoch = round(history.history['loss'][i], 5)
        val_mse_epoch = round(history.history['val_loss'][i], 5)
        print(f"Epoch {i+1}, Train MSE: {train_mse_epoch}, Validation MSE: {val_mse_epoch}")
        train_mse.append(train_mse_epoch)
        val_mse.append(val_mse_epoch)

    # Append the mean MSE of training and validation sets for the current fold to the lists
    train_mse.append(np.mean(history.history['loss']))
    val_mse.append(np.mean(history.history['val_loss']))

# Print the final mean and standard deviation of MSE for training and validation sets across all folds
print("\nFinal results:")
print(f"Mean Train MSE: {np.mean(train_mse):.5f}")
print(f"Mean Validation MSE: {np.mean(val_mse):.5f}")

# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Fold 1
# ------------------------------------
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA03529A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA03529A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6438/6479 [============================>.] - ETA: 0s - loss: 1.0632WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0381E828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA0381E828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 18s 3ms/step - loss: 1.0612 - val_loss: 0.7462
# Epoch 2/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.9166 - val_loss: 0.7103
# Epoch 3/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8944 - val_loss: 0.6970
# Epoch 4/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8828 - val_loss: 0.6892
# Epoch 5/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8763 - val_loss: 0.6989
# Epoch 6/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8710 - val_loss: 0.6830
# Epoch 7/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8674 - val_loss: 0.6787
# Epoch 8/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8638 - val_loss: 0.6767
# Epoch 9/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.8615 - val_loss: 0.6746
# Epoch 10/10
# 6479/6479 [==============================] - 15s 2ms/step - loss: 0.8596 - val_loss: 0.6726
# Epoch 1, Train MSE: 1.06117, Validation MSE: 0.74621
# Epoch 2, Train MSE: 0.91665, Validation MSE: 0.71027
# Epoch 3, Train MSE: 0.89445, Validation MSE: 0.69695
# Epoch 4, Train MSE: 0.88285, Validation MSE: 0.6892
# Epoch 5, Train MSE: 0.87627, Validation MSE: 0.69891
# Epoch 6, Train MSE: 0.871, Validation MSE: 0.68301
# Epoch 7, Train MSE: 0.86744, Validation MSE: 0.67872
# Epoch 8, Train MSE: 0.86382, Validation MSE: 0.67668
# Epoch 9, Train MSE: 0.86145, Validation MSE: 0.67459
# Epoch 10, Train MSE: 0.85956, Validation MSE: 0.67262
#
# Fold 2
# ------------------------------------
# Epoch 1/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.6643 - val_loss: 0.9293
# Epoch 2/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.6628 - val_loss: 0.9291
# Epoch 3/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.6617 - val_loss: 0.9288
# Epoch 4/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.6608 - val_loss: 0.9273
# Epoch 5/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.6600 - val_loss: 0.9250
# Epoch 6/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.6593 - val_loss: 0.9245
# Epoch 7/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.6586 - val_loss: 0.9243
# Epoch 8/10
# 6479/6479 [==============================] - 20s 3ms/step - loss: 0.6581 - val_loss: 0.9233
# Epoch 9/10
# 6479/6479 [==============================] - 17s 3ms/step - loss: 0.6575 - val_loss: 0.9229
# Epoch 10/10
# 6479/6479 [==============================] - 16s 2ms/step - loss: 0.6571 - val_loss: 0.9224
# Epoch 1, Train MSE: 0.66431, Validation MSE: 0.92931
# Epoch 2, Train MSE: 0.66278, Validation MSE: 0.92905
# Epoch 3, Train MSE: 0.6617, Validation MSE: 0.92877
# Epoch 4, Train MSE: 0.66078, Validation MSE: 0.92726
# Epoch 5, Train MSE: 0.65997, Validation MSE: 0.92496
# Epoch 6, Train MSE: 0.65925, Validation MSE: 0.92451
# Epoch 7, Train MSE: 0.65862, Validation MSE: 0.92428
# Epoch 8, Train MSE: 0.65806, Validation MSE: 0.92329
# Epoch 9, Train MSE: 0.65754, Validation MSE: 0.92288
# Epoch 10, Train MSE: 0.65707, Validation MSE: 0.92244
#
# Final results:
# Mean Train MSE: 0.77774
# Mean Validation MSE: 0.80920

# %%
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping
np.random.seed(42)
# Define the autoencoder architecture
input_dim = X_train_resampled_final.shape[1]
encoding_dim = 40
decoding_dim = 10

input_layer = Input(shape=(input_dim,))
#hidden_layer = Dense(encoding_dim, activation='relu')(input_layer)

# Add L1 regularization to the hidden layer
hidden_layer = Dense(encoding_dim, activation='relu', kernel_regularizer=regularizers.l1(0.025))(input_layer)

output_layer = Dense(decoding_dim, activation='sigmoid')(hidden_layer)

# Define the optimizer with the desired learning rate

opt = Adam(lr= 0.002)
# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
#autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.compile(optimizer=opt, loss='mse')

# Define the number of folds for cross-validation
n_splits = 2
kf = KFold(n_splits=n_splits)

# Define lists to store the MSE of training and validation sets for each fold
train_mse = []
val_mse = []
recon_errors = []
test_mse = []

for fold, (train_index, val_index) in enumerate(kf.split(X_train_resampled_final)):
    # Print the fold number
    print(f"\nFold {fold+1}")
    print("------------------------------------")
    
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_train_resampled_final[train_index], X_train_resampled_final[val_index]
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Fit the autoencoder on the training set for the current fold
    history = autoencoder.fit(X_train_fold, X_train_fold, epochs=5, batch_size=32, verbose=1, validation_data=(X_val_fold, X_val_fold), callbacks=[early_stopping])
    
    for i in range(len(history.history['loss'])):
        train_mse_epoch = round(history.history['loss'][i], 5)
        val_mse_epoch = round(history.history['val_loss'][i], 5)
        print(f"Epoch {i+1}, Train MSE: {train_mse_epoch}, Validation MSE: {val_mse_epoch}")
        train_mse.append(train_mse_epoch)
        val_mse.append(val_mse_epoch)

    # Append the mean MSE of training and validation sets for the current fold to the lists
    train_mse.append(np.mean(history.history['loss']))
    val_mse.append(np.mean(history.history['val_loss']))

    
#     # compute the reconstruction error for the test data
#     recon_error = autoencoder.evaluate(X_test, X_test, verbose=0)
#     recon_errors.append(recon_error)

# Print the final mean and standard deviation of MSE for training and validation sets across all folds
print("\nFinal results:")
print(f"Mean Train MSE: {np.mean(train_mse):.5f}")
print(f"Mean Validation MSE: {np.mean(val_mse):.5f}")

# Plot the MSE of training and validation sets against the number of epochs
epochs = range(1, len(mean_train_mse)+1)
plt.plot(epochs, mean_train_mse, 'b', label='Training MSE')
plt.fill_between(epochs, mean_train_mse - std_train_mse, mean_train_mse + std_train_mse, alpha=0.2, color='b')
plt.plot(epochs, mean_val_mse, 'r', label='Validation MSE')
plt.fill_between(epochs, mean_val_mse - std_val_mse, mean_val_mse + std_val_mse, alpha=0.2, color='r')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()
# Out:
# Fold 1
# ------------------------------------
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA738DE558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001FA738DE558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6475/6479 [============================>.] - ETA: 0s - loss: 0.9627WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA6CBCA3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001FA6CBCA3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6479/6479 [==============================] - 20s 3ms/step - loss: 0.9626 - val_loss: 0.7020
# Epoch 2/5
# 6479/6479 [==============================] - 20s 3ms/step - loss: 0.8807 - val_loss: 0.6810
# Epoch 3/5
# 6479/6479 [==============================] - 20s 3ms/step - loss: 0.8647 - val_loss: 0.6693
# Epoch 4/5
# 6479/6479 [==============================] - 23s 4ms/step - loss: 0.8572 - val_loss: 0.6711
# Epoch 5/5
# 6479/6479 [==============================] - 25s 4ms/step - loss: 0.8535 - val_loss: 0.6724
# Epoch 1, Train MSE: 0.96256, Validation MSE: 0.702
# Epoch 2, Train MSE: 0.88069, Validation MSE: 0.681
# Epoch 3, Train MSE: 0.86471, Validation MSE: 0.66928
# Epoch 4, Train MSE: 0.85723, Validation MSE: 0.67109
# Epoch 5, Train MSE: 0.85351, Validation MSE: 0.67237
#
# Fold 2
# ------------------------------------
# Epoch 1/5
# 6479/6479 [==============================] - 27s 4ms/step - loss: 0.6586 - val_loss: 0.9289
# Epoch 2/5
# 6479/6479 [==============================] - 20s 3ms/step - loss: 0.6564 - val_loss: 0.9269
# Epoch 3/5
# 6479/6479 [==============================] - 19s 3ms/step - loss: 0.6387 - val_loss: 0.9009
# Epoch 4/5
# 6479/6479 [==============================] - 19s 3ms/step - loss: 0.5542 - val_loss: 0.8861
# Epoch 5/5
# 6479/6479 [==============================] - 20s 3ms/step - loss: 0.5456 - val_loss: 0.8834
# Epoch 1, Train MSE: 0.65864, Validation MSE: 0.92886
# Epoch 2, Train MSE: 0.65637, Validation MSE: 0.9269
# Epoch 3, Train MSE: 0.63872, Validation MSE: 0.90095
# Epoch 4, Train MSE: 0.55423, Validation MSE: 0.88614
# Epoch 5, Train MSE: 0.54564, Validation MSE: 0.88337
#
# Final results:
# Mean Train MSE: 0.74723
# Mean Validation MSE: 0.79220
