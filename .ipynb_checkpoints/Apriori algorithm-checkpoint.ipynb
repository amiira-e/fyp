# %%
import numpy as np
import pandas as pd
df_sample=pd.read_csv(r"C:\Users\23059\OneDrive\Desktop\Amiira\Y3S1\fyp\sample.csv")

# %% [markdown]
# ## Sampling

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['type'])
label
df_sample.drop("type", axis=1, inplace=True)
df_sample["type"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['nameDest'])
label
df_sample.drop("nameDest", axis=1, inplace=True)
df_sample["nameDest"] = label

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df_sample['nameOrig'])
label
df_sample.drop("nameOrig", axis=1, inplace=True)
df_sample["nameOrig"] = label

# %%
X = df_sample.drop('isFraud', axis=1)
# Separate the target variable
y = df_sample['isFraud']

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

#Upsampling via SMOTE
smote = SMOTE(sampling_strategy=0.5, random_state=0)

#Downsample via RandomUnderSampler
rus = RandomUnderSampler(sampling_strategy=0.7, random_state=0)

#Application of the resampling methods
X_resampled, y_resampled = smote.fit_resample(X, y)
X_resampled, y_resampled = rus.fit_resample(X_resampled, y_resampled)

# %%
# assuming your dataframe is named df_sample
amount_min = df_sample['step'].min()
amount_max = df_sample['step'].max()

print("Minimum amount:", amount_min)
print("Maximum amount:", amount_max)
# Out:
# Minimum amount: 1
# Maximum amount: 743

# %%
counts = y_resampled.value_counts()
print(counts)
# Out:
# 0    499371
# 1    349560
# Name: isFraud, dtype: int64

# %%
# combine X_resampled and y_resampled back to a dataframe
df_sample = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['isFraud'])], axis=1)

# %% [markdown]
# Nominal dataframe

# %%
# Count the number of occurrences of 0 and 1
counts = df_sample['isFraud'].value_counts()

# Print the counts
print("Number of 0s:", counts[0])
print("Number of 1s:", counts[1])

# %%
from sklearn.cluster import KMeans

# Select continuous variables along with
continuous_vars = ['step','amount','isFraud']

# Normalize the data
normalized_df = (df_sample[continuous_vars] - df_sample[continuous_vars].mean()) / df_sample[continuous_vars].std()

# Determine optimal number of clusters
kmeans_kwargs = {"init": "random", "n_init": 10, "max_iter": 50, "random_state": 42}
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(normalized_df)
    sse.append(kmeans.inertia_)
    
# Elbow method 
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# Apply K-Means clustering
kmeans = KMeans(n_clusters=3, **kmeans_kwargs)
kmeans.fit(normalized_df)
clusters = kmeans.predict(normalized_df)

# Assign nominal values
cluster_df = pd.DataFrame()
for var in continuous_vars:
    cluster_centers = kmeans.cluster_centers_[:, continuous_vars.index(var)]
    col_name = var + '_cluster'
    cluster_df[col_name] = kmeans.predict(normalized_df)
    
    # Replace cluster labels with desired values
    if var == 'isFraud':
        cluster_df[col_name] = cluster_df[col_name].apply(lambda x: 'Fraud' if x == 1 else 'No fraud')
    elif var == 'amount':
        cluster_labels = ['Low', 'Medium', 'High']
        normalized_df['amount_bin'], bin_edges = pd.qcut(normalized_df['amount'], q=3, labels=cluster_labels, retbins=True)
        cluster_df[col_name] = normalized_df['amount_bin']
        print(f"The bin edges for amount are {bin_edges}")
        normalized_df = normalized_df.drop(['amount_bin'], axis=1)
    elif var == 'step':
        bin_edges = [-np.inf, 186, 372, 558, np.inf] # Divide into four bins based on quartiles
        cluster_labels = ['1-186', '187-372', '373-558', '559-743']
        cluster_df[col_name] = pd.cut(df_sample['step'], bins=bin_edges, labels=cluster_labels)
        print(f"The bin edges for step are {bin_edges}")
        
new_df1 = pd.DataFrame()
# Merge nominal variables with original dataset
new_df1 = pd.concat([new_df1, cluster_df], axis=1)
# Out:
# The bin edges for step are [-inf, 186, 372, 558, inf]
# The bin edges for amount are [-0.405032   -0.37282174 -0.24913892 37.44097044]

# %%
new_df1.head(20)
# Out:
#    step_cluster amount_cluster isFraud_cluster
# 0         1-186            Low           Fraud
# 1       187-372            Low           Fraud
# 2       373-558            Low           Fraud
# 3       187-372            Low           Fraud
# 4       187-372            Low           Fraud
# 5       187-372         Medium           Fraud
# 6       187-372           High           Fraud
# 7       187-372            Low           Fraud
# 8       187-372           High           Fraud
# 9         1-186         Medium           Fraud
# 10      373-558           High           Fraud
# 11        1-186            Low           Fraud
# 12        1-186         Medium           Fraud
# 13      187-372            Low           Fraud
# 14      187-372         Medium           Fraud
# 15      559-743            Low           Fraud
# 16      187-372           High           Fraud
# 17        1-186           High           Fraud
# 18      187-372         Medium           Fraud
# 19      373-558            Low           Fraud

# %%
# Count number of times No fraud occurs in 'isFraud_cluster'
no_fraud_count = new_df1['isFraud_cluster'].value_counts()['No fraud']

# Print the count
print("Number of times 'No fraud' occurs in 'isFraud_cluster':", no_fraud_count)

# %%
# Count number of times No fraud occurs in 'isFraud_cluster'
no_fraud_count = new_df1['isFraud_cluster'].value_counts()['Fraud']

# Print the count
print("Number of times 'No fraud' occurs in 'isFraud_cluster':", no_fraud_count)

# %%
cluster_df['amount_cluster'].value_counts()

# %% [markdown]
#  np.percentile function to create bins based on percentiles of the amount variable.

# %%
# Determine range of values for "Low" bin
low_bin = pd.Interval(left=kmeans.cluster_centers_[0, continuous_vars.index('amount')] - normalized_df['amount'].std(),
                      right=kmeans.cluster_centers_[0, continuous_vars.index('amount')] + normalized_df['amount'].std())
print(low_bin)

# %%
# Determine range of values for "Medium" bin
medium_bin = pd.Interval(left=kmeans.cluster_centers_[1, continuous_vars.index('amount')] - normalized_df['amount'].std(),
                         right=kmeans.cluster_centers_[1, continuous_vars.index('amount')] + normalized_df['amount'].std())
print(medium_bin)

# Determine range of values for "High" bin
high_bin = pd.Interval(left=kmeans.cluster_centers_[2, continuous_vars.index('amount')] - normalized_df['amount'].std(),
                       right=kmeans.cluster_centers_[2, continuous_vars.index('amount')] + normalized_df['amount'].std())
print(high_bin)

# %%
# import pandas as pd

# # One-hot encode the categorical columns
# df_encoded = pd.get_dummies(new_df1, prefix='', prefix_sep='')

# # Concatenate the binary columns
# df_boolean = df_encoded.groupby(level=0, axis=1).max()

# # Print the boolean data
# print(df_boolean)

# %%
# import pandas as pd

# # Convert the categorical columns to boolean values
# df_bool = pd.get_dummies(new_df1, columns=['step_cluster', 'amount_cluster', 'isFraud_cluster'], dtype=bool)

# # Save the transformed dataset
# df_bool.to_csv('fraud_dataset_binary1.csv', index=False)

# %%
import pandas as pd

# Convert the categorical columns to boolean values and then to integers
df_bool = pd.get_dummies(new_df1, columns=['step_cluster', 'amount_cluster', 'isFraud_cluster'], dtype=bool).astype(int)

# Replace False with 0 and True with 1
df_bool = df_bool.replace({False: 0, True: 1})

# Save the transformed dataset
df_bool.to_csv('fraud_dataset_binary1.csv', index=False)

# %%
df_bool.head(10)
# Out:
#    step_cluster_1-186  step_cluster_187-372  step_cluster_373-558  \
# 0                   1                     0                     0
# 1                   0                     1                     0
# 2                   0                     0                     1
# 3                   0                     1                     0
# 4                   0                     1                     0
# 5                   0                     1                     0
# 6                   0                     1                     0
# 7                   0                     1                     0
# 8                   0                     1                     0
# 9                   1                     0                     0
#
#    step_cluster_559-743  amount_cluster_Low  amount_cluster_Medium  \
# 0                     0                   1                      0
# 1                     0                   1                      0
# 2                     0                   1                      0
# 3                     0                   1                      0
# 4                     0                   1                      0
# 5                     0                   0                      1
# 6                     0                   0                      0
# 7                     0                   1                      0
# 8                     0                   0                      0
# 9                     0                   0                      1
#
#    amount_cluster_High  isFraud_cluster_Fraud  isFraud_cluster_No fraud
# 0                    0                      1                         0
# 1                    0                      1                         0
# 2                    0                      1                         0
# 3                    0                      1                         0
# 4                    0                      1                         0
# 5                    0                      1                         0
# 6                    1                      1                         0
# 7                    0                      1                         0
# 8                    1                      1                         0
# 9                    0                      1                         0

# %%
# import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# Generate frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(df_bool, min_support=0.1, use_colnames=True)
# Out:
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,

# %%
# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Print the rules
print(rules.to_string())
# Out:
#                                        antecedents                                     consequents  antecedent support  consequent support   support  confidence      lift  leverage  conviction
# 0                             (step_cluster_1-186)                            (amount_cluster_Low)            0.276959            0.333333  0.110237    0.398028  1.194085  0.017918    1.107472
# 1                             (amount_cluster_Low)                            (step_cluster_1-186)            0.333333            0.276959  0.110237    0.330712  1.194085  0.017918    1.080314
# 2                             (step_cluster_1-186)                         (isFraud_cluster_Fraud)            0.276959            0.587249  0.207369    0.748736  1.274988  0.044725    1.642696
# 3                          (isFraud_cluster_Fraud)                            (step_cluster_1-186)            0.587249            0.276959  0.207369    0.353119  1.274988  0.044725    1.117735
# 4                           (step_cluster_187-372)                            (amount_cluster_Low)            0.413858            0.333333  0.150579    0.363842  1.091525  0.012626    1.047957
# 5                             (amount_cluster_Low)                          (step_cluster_187-372)            0.333333            0.413858  0.150579    0.451736  1.091525  0.012626    1.069088
# 6                           (step_cluster_187-372)                         (amount_cluster_Medium)            0.413858            0.333333  0.142253    0.343724  1.031172  0.004300    1.015833
# 7                          (amount_cluster_Medium)                          (step_cluster_187-372)            0.333333            0.413858  0.142253    0.426759  1.031172  0.004300    1.022505
# 8                           (step_cluster_187-372)                         (isFraud_cluster_Fraud)            0.413858            0.587249  0.280330    0.677358  1.153443  0.037292    1.279285
# 9                          (isFraud_cluster_Fraud)                          (step_cluster_187-372)            0.587249            0.413858  0.280330    0.477362  1.153443  0.037292    1.121506
# 10                          (step_cluster_373-558)                      (isFraud_cluster_No fraud)            0.216257            0.412751  0.134367    0.621329  1.505338  0.045107    1.550818
# 11                      (isFraud_cluster_No fraud)                          (step_cluster_373-558)            0.412751            0.216257  0.134367    0.325539  1.505338  0.045107    1.162030
# 12                         (isFraud_cluster_Fraud)                            (amount_cluster_Low)            0.587249            0.333333  0.273575    0.465858  1.397574  0.077825    1.248107
# 13                            (amount_cluster_Low)                         (isFraud_cluster_Fraud)            0.333333            0.587249  0.273575    0.820724  1.397574  0.077825    2.302320
# 14                         (isFraud_cluster_Fraud)                         (amount_cluster_Medium)            0.587249            0.333333  0.222881    0.379535  1.138604  0.027132    1.074463
# 15                         (amount_cluster_Medium)                         (isFraud_cluster_Fraud)            0.333333            0.587249  0.222881    0.668644  1.138604  0.027132    1.245643
# 16                           (amount_cluster_High)                      (isFraud_cluster_No fraud)            0.333333            0.412751  0.242540    0.727621  1.762858  0.104957    2.156000
# 17                      (isFraud_cluster_No fraud)                           (amount_cluster_High)            0.412751            0.333333  0.242540    0.587619  1.762858  0.104957    1.616629
# 18   (step_cluster_187-372, isFraud_cluster_Fraud)                            (amount_cluster_Low)            0.280330            0.333333  0.131909    0.470550  1.411651  0.038466    1.259169
# 19      (step_cluster_187-372, amount_cluster_Low)                         (isFraud_cluster_Fraud)            0.150579            0.587249  0.131909    0.876016  1.491728  0.043482    3.329065
# 20     (isFraud_cluster_Fraud, amount_cluster_Low)                          (step_cluster_187-372)            0.273575            0.413858  0.131909    0.482170  1.165061  0.018688    1.131919
# 21                          (step_cluster_187-372)     (isFraud_cluster_Fraud, amount_cluster_Low)            0.413858            0.273575  0.131909    0.318731  1.165061  0.018688    1.066283
# 22                         (isFraud_cluster_Fraud)      (step_cluster_187-372, amount_cluster_Low)            0.587249            0.150579  0.131909    0.224623  1.491728  0.043482    1.095494
# 23                            (amount_cluster_Low)   (step_cluster_187-372, isFraud_cluster_Fraud)            0.333333            0.280330  0.131909    0.395728  1.411651  0.038466    1.190970
# 24   (step_cluster_187-372, isFraud_cluster_Fraud)                         (amount_cluster_Medium)            0.280330            0.333333  0.106912    0.381379  1.144138  0.013469    1.077666
# 25   (step_cluster_187-372, amount_cluster_Medium)                         (isFraud_cluster_Fraud)            0.142253            0.587249  0.106912    0.751563  1.279803  0.023374    1.661390
# 26  (isFraud_cluster_Fraud, amount_cluster_Medium)                          (step_cluster_187-372)            0.222881            0.413858  0.106912    0.479681  1.159048  0.014671    1.126506
# 27                          (step_cluster_187-372)  (isFraud_cluster_Fraud, amount_cluster_Medium)            0.413858            0.222881  0.106912    0.258330  1.159048  0.014671    1.047796
# 28                         (isFraud_cluster_Fraud)   (step_cluster_187-372, amount_cluster_Medium)            0.587249            0.142253  0.106912    0.182056  1.279803  0.023374    1.048662
# 29                         (amount_cluster_Medium)   (step_cluster_187-372, isFraud_cluster_Fraud)            0.333333            0.280330  0.106912    0.320736  1.144138  0.013469    1.059485

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# Generate frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(df_bool, min_support=0.1, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Print the rules
for index, rule in rules.iterrows():
    antecedents = list(rule['antecedents'])
    consequents = list(rule['consequents'])
    support = rule['support']
    confidence = rule['confidence']
    lift = rule['lift']
    
    print(f"Rule {index+1}:")
    print(f"Antecedents: {antecedents}")
    print(f"Consequents: {consequents}")
    print(f"Support: {support:.3f}")
    print(f"Confidence: {confidence:.3f}")
    print(f"Lift: {lift:.3f}")
    print("-"*50)
    
print(f"Number of rules: {len(rules)}")
# Out:
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# Rule 1:
# Antecedents: ['step_cluster_1-186']
# Consequents: ['amount_cluster_Low']
# Support: 0.110
# Confidence: 0.398
# Lift: 1.194
# --------------------------------------------------
# Rule 2:
# Antecedents: ['amount_cluster_Low']
# Consequents: ['step_cluster_1-186']
# Support: 0.110
# Confidence: 0.331
# Lift: 1.194
# --------------------------------------------------
# Rule 3:
# Antecedents: ['step_cluster_1-186']
# Consequents: ['isFraud_cluster_Fraud']
# Support: 0.207
# Confidence: 0.749
# Lift: 1.275
# --------------------------------------------------
# Rule 4:
# Antecedents: ['isFraud_cluster_Fraud']
# Consequents: ['step_cluster_1-186']
# Support: 0.207
# Confidence: 0.353
# Lift: 1.275
# --------------------------------------------------
# Rule 5:
# Antecedents: ['step_cluster_187-372']
# Consequents: ['amount_cluster_Low']
# Support: 0.151
# Confidence: 0.364
# Lift: 1.092
# --------------------------------------------------
# Rule 6:
# Antecedents: ['amount_cluster_Low']
# Consequents: ['step_cluster_187-372']
# Support: 0.151
# Confidence: 0.452
# Lift: 1.092
# --------------------------------------------------
# Rule 7:
# Antecedents: ['step_cluster_187-372']
# Consequents: ['amount_cluster_Medium']
# Support: 0.142
# Confidence: 0.344
# Lift: 1.031
# --------------------------------------------------
# Rule 8:
# Antecedents: ['amount_cluster_Medium']
# Consequents: ['step_cluster_187-372']
# Support: 0.142
# Confidence: 0.427
# Lift: 1.031
# --------------------------------------------------
# Rule 9:
# Antecedents: ['step_cluster_187-372']
# Consequents: ['isFraud_cluster_Fraud']
# Support: 0.280
# Confidence: 0.677
# Lift: 1.153
# --------------------------------------------------
# Rule 10:
# Antecedents: ['isFraud_cluster_Fraud']
# Consequents: ['step_cluster_187-372']
# Support: 0.280
# Confidence: 0.477
# Lift: 1.153
# --------------------------------------------------
# Rule 11:
# Antecedents: ['step_cluster_373-558']
# Consequents: ['isFraud_cluster_No fraud']
# Support: 0.134
# Confidence: 0.621
# Lift: 1.505
# --------------------------------------------------
# Rule 12:
# Antecedents: ['isFraud_cluster_No fraud']
# Consequents: ['step_cluster_373-558']
# Support: 0.134
# Confidence: 0.326
# Lift: 1.505
# --------------------------------------------------
# Rule 13:
# Antecedents: ['isFraud_cluster_Fraud']
# Consequents: ['amount_cluster_Low']
# Support: 0.274
# Confidence: 0.466
# Lift: 1.398
# --------------------------------------------------
# Rule 14:
# Antecedents: ['amount_cluster_Low']
# Consequents: ['isFraud_cluster_Fraud']
# Support: 0.274
# Confidence: 0.821
# Lift: 1.398
# --------------------------------------------------
# Rule 15:
# Antecedents: ['isFraud_cluster_Fraud']
# Consequents: ['amount_cluster_Medium']
# Support: 0.223
# Confidence: 0.380
# Lift: 1.139
# --------------------------------------------------
# Rule 16:
# Antecedents: ['amount_cluster_Medium']
# Consequents: ['isFraud_cluster_Fraud']
# Support: 0.223
# Confidence: 0.669
# Lift: 1.139
# --------------------------------------------------
# Rule 17:
# Antecedents: ['amount_cluster_High']
# Consequents: ['isFraud_cluster_No fraud']
# Support: 0.243
# Confidence: 0.728
# Lift: 1.763
# --------------------------------------------------
# Rule 18:
# Antecedents: ['isFraud_cluster_No fraud']
# Consequents: ['amount_cluster_High']
# Support: 0.243
# Confidence: 0.588
# Lift: 1.763
# --------------------------------------------------
# Rule 19:
# Antecedents: ['step_cluster_187-372', 'isFraud_cluster_Fraud']
# Consequents: ['amount_cluster_Low']
# Support: 0.132
# Confidence: 0.471
# Lift: 1.412
# --------------------------------------------------
# Rule 20:
# Antecedents: ['step_cluster_187-372', 'amount_cluster_Low']
# Consequents: ['isFraud_cluster_Fraud']
# Support: 0.132
# Confidence: 0.876
# Lift: 1.492
# --------------------------------------------------
# Rule 21:
# Antecedents: ['isFraud_cluster_Fraud', 'amount_cluster_Low']
# Consequents: ['step_cluster_187-372']
# Support: 0.132
# Confidence: 0.482
# Lift: 1.165
# --------------------------------------------------
# Rule 22:
# Antecedents: ['step_cluster_187-372']
# Consequents: ['isFraud_cluster_Fraud', 'amount_cluster_Low']
# Support: 0.132
# Confidence: 0.319
# Lift: 1.165
# --------------------------------------------------
# Rule 23:
# Antecedents: ['isFraud_cluster_Fraud']
# Consequents: ['step_cluster_187-372', 'amount_cluster_Low']
# Support: 0.132
# Confidence: 0.225
# Lift: 1.492
# --------------------------------------------------
# Rule 24:
# Antecedents: ['amount_cluster_Low']
# Consequents: ['step_cluster_187-372', 'isFraud_cluster_Fraud']
# Support: 0.132
# Confidence: 0.396
# Lift: 1.412
# --------------------------------------------------
# Rule 25:
# Antecedents: ['step_cluster_187-372', 'isFraud_cluster_Fraud']
# Consequents: ['amount_cluster_Medium']
# Support: 0.107
# Confidence: 0.381
# Lift: 1.144
# --------------------------------------------------
# Rule 26:
# Antecedents: ['step_cluster_187-372', 'amount_cluster_Medium']
# Consequents: ['isFraud_cluster_Fraud']
# Support: 0.107
# Confidence: 0.752
# Lift: 1.280
# --------------------------------------------------
# Rule 27:
# Antecedents: ['isFraud_cluster_Fraud', 'amount_cluster_Medium']
# Consequents: ['step_cluster_187-372']
# Support: 0.107
# Confidence: 0.480
# Lift: 1.159
# --------------------------------------------------
# Rule 28:
# Antecedents: ['step_cluster_187-372']
# Consequents: ['isFraud_cluster_Fraud', 'amount_cluster_Medium']
# Support: 0.107
# Confidence: 0.258
# Lift: 1.159
# --------------------------------------------------
# Rule 29:
# Antecedents: ['isFraud_cluster_Fraud']
# Consequents: ['step_cluster_187-372', 'amount_cluster_Medium']
# Support: 0.107
# Confidence: 0.182
# Lift: 1.280
# --------------------------------------------------
# Rule 30:
# Antecedents: ['amount_cluster_Medium']
# Consequents: ['step_cluster_187-372', 'isFraud_cluster_Fraud']
# Support: 0.107
# Confidence: 0.321
# Lift: 1.144
# --------------------------------------------------
# Number of rules: 30

# %%
# Generate frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(df_bool, min_support=0.1, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.2)

# Filter rules that include isFraud_cluster_Fraud in either antecedents or consequents
rules_with_fraud = rules[
    (rules["consequents"].astype(str).str.contains("isFraud_cluster_Fraud"))
]

# Print the filtered rules
print(rules_with_fraud.to_string())
# Out:
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#                                       antecedents                                     consequents  antecedent support  consequent support   support  confidence      lift  leverage  conviction
# 2                            (step_cluster_1-186)                         (isFraud_cluster_Fraud)            0.276959            0.587249  0.207369    0.748736  1.274988  0.044725    1.642696
# 10                         (step_cluster_187-372)                         (isFraud_cluster_Fraud)            0.413858            0.587249  0.280330    0.677358  1.153443  0.037292    1.279285
# 17                           (amount_cluster_Low)                         (isFraud_cluster_Fraud)            0.333333            0.587249  0.273575    0.820724  1.397574  0.077825    2.302320
# 19                        (amount_cluster_Medium)                         (isFraud_cluster_Fraud)            0.333333            0.587249  0.222881    0.668644  1.138604  0.027132    1.245643
# 25     (step_cluster_187-372, amount_cluster_Low)                         (isFraud_cluster_Fraud)            0.150579            0.587249  0.131909    0.876016  1.491728  0.043482    3.329065
# 27                         (step_cluster_187-372)     (isFraud_cluster_Fraud, amount_cluster_Low)            0.413858            0.273575  0.131909    0.318731  1.165061  0.018688    1.066283
# 29                           (amount_cluster_Low)   (step_cluster_187-372, isFraud_cluster_Fraud)            0.333333            0.280330  0.131909    0.395728  1.411651  0.038466    1.190970
# 31  (step_cluster_187-372, amount_cluster_Medium)                         (isFraud_cluster_Fraud)            0.142253            0.587249  0.106912    0.751563  1.279803  0.023374    1.661390
# 33                         (step_cluster_187-372)  (isFraud_cluster_Fraud, amount_cluster_Medium)            0.413858            0.222881  0.106912    0.258330  1.159048  0.014671    1.047796
# 35                        (amount_cluster_Medium)   (step_cluster_187-372, isFraud_cluster_Fraud)            0.333333            0.280330  0.106912    0.320736  1.144138  0.013469    1.059485

# %%
# Generate frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(df_bool, min_support=0.1, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.2)

# Filter rules that include isFraud_cluster_Fraud in either antecedents or consequents
rules_with_fraud = rules[
    (rules["consequents"].astype(str).str.contains("isFraud_cluster_Fraud"))
]

# Print the filtered rules
for index, row in rules_with_fraud.iterrows():
    print(row.to_string())
    print("\n")

# Decrease the font size of the output
from IPython.core.display import HTML
HTML("<style>.output {font-size: 12px;}</style>")
# Out:
# C:\Users\23059\anaconda3\envs\test2\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# antecedents              (step_cluster_1-186)
# consequents           (isFraud_cluster_Fraud)
# antecedent support                   0.276959
# consequent support                   0.587249
# support                              0.207369
# confidence                           0.748736
# lift                                 1.274988
# leverage                             0.044725
# conviction                           1.642696
#
#
# antecedents            (step_cluster_187-372)
# consequents           (isFraud_cluster_Fraud)
# antecedent support                   0.413858
# consequent support                   0.587249
# support                               0.28033
# confidence                           0.677358
# lift                                 1.153443
# leverage                             0.037292
# conviction                           1.279285
#
#
# antecedents              (amount_cluster_Low)
# consequents           (isFraud_cluster_Fraud)
# antecedent support                   0.333333
# consequent support                   0.587249
# support                              0.273575
# confidence                           0.820724
# lift                                 1.397574
# leverage                             0.077825
# conviction                            2.30232
#
#
# antecedents           (amount_cluster_Medium)
# consequents           (isFraud_cluster_Fraud)
# antecedent support                   0.333333
# consequent support                   0.587249
# support                              0.222881
# confidence                           0.668644
# lift                                 1.138604
# leverage                             0.027132
# conviction                           1.245643
#
#
# antecedents           (step_cluster_187-372, amount_cluster_Low)
# consequents                              (isFraud_cluster_Fraud)
# antecedent support                                      0.150579
# consequent support                                      0.587249
# support                                                 0.131909
# confidence                                              0.876016
# lift                                                    1.491728
# leverage                                                0.043482
# conviction                                              3.329065
#
#
# antecedents                                (step_cluster_187-372)
# consequents           (isFraud_cluster_Fraud, amount_cluster_Low)
# antecedent support                                       0.413858
# consequent support                                       0.273575
# support                                                  0.131909
# confidence                                               0.318731
# lift                                                     1.165061
# leverage                                                 0.018688
# conviction                                               1.066283
#
#
# antecedents                                    (amount_cluster_Low)
# consequents           (step_cluster_187-372, isFraud_cluster_Fraud)
# antecedent support                                         0.333333
# consequent support                                          0.28033
# support                                                    0.131909
# confidence                                                 0.395728
# lift                                                       1.411651
# leverage                                                   0.038466
# conviction                                                  1.19097
#
#
# antecedents           (step_cluster_187-372, amount_cluster_Medium)
# consequents                                 (isFraud_cluster_Fraud)
# antecedent support                                         0.142253
# consequent support                                         0.587249
# support                                                    0.106912
# confidence                                                 0.751563
# lift                                                       1.279803
# leverage                                                   0.023374
# conviction                                                  1.66139
#
#
# antecedents                                   (step_cluster_187-372)
# consequents           (isFraud_cluster_Fraud, amount_cluster_Medium)
# antecedent support                                          0.413858
# consequent support                                          0.222881
# support                                                     0.106912
# confidence                                                   0.25833
# lift                                                        1.159048
# leverage                                                    0.014671
# conviction                                                  1.047796
#
#
# antecedents                                 (amount_cluster_Medium)
# consequents           (step_cluster_187-372, isFraud_cluster_Fraud)
# antecedent support                                         0.333333
# consequent support                                          0.28033
# support                                                    0.106912
# confidence                                                 0.320736
# lift                                                       1.144138
# leverage                                                   0.013469
# conviction                                                 1.059485
# <style>.output {font-size: 12px;}</style>

# %%
# Count number of items in each cluster
cluster_counts = cluster_df.apply(lambda x: x.value_counts()).T.stack()

# Create new dataframe with cluster counts
cluster_counts_df = pd.DataFrame(cluster_counts, columns=['Count']).reset_index()
cluster_counts_df.columns = ['Variable', 'Cluster', 'Count']
cluster_counts_df = cluster_counts_df.sort_values(['Variable', 'Cluster']).reset_index(drop=True)

print(cluster_counts_df)

# %% [markdown]
# By transforming the continuous variables into categorical variables, the author can use them as inputs to a model for predicting the "Fraud class" variable.

# %%
df_sample_subset = df_sample_orig.iloc[:50, :]

# %%
df_sample_subset
# Out:
#     step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0    259  CASH_OUT   246917.44  C1498821826           0.00            0.00
# 1    161   CASH_IN   165577.48  C1959842869      242080.31       407657.78
# 2    331   PAYMENT    11147.81   C690176304       21271.00        10123.19
# 3    304   PAYMENT     3758.44  C1065078045           0.00            0.00
# 4    355  CASH_OUT   295770.07   C278303549           0.00            0.00
# 5     95   CASH_IN   201288.36   C665915260     1225323.20      1426611.57
# 6    279  TRANSFER   295733.65     C5902624           0.00            0.00
# 7     43   PAYMENT     8587.65  C1020057479      287197.84       278610.18
# 8    203   CASH_IN     6324.85  C1655576665      637439.64       643764.49
# 9    691   CASH_IN   186825.78   C863136282     4048495.82      4235321.60
# 10   310   PAYMENT    28960.08  C1090990820       49793.00        20832.92
# 11    94   CASH_IN   263629.97  C1969693521     2223455.42      2487085.39
# 12   187   PAYMENT     7708.28  C1453929454           0.00            0.00
# 13   356  CASH_OUT   255265.11   C525712630       79560.00            0.00
# 14   280   CASH_IN   220943.22  C1193018207     1068355.69      1289298.92
# 15    38   PAYMENT    20168.79  C1240927993      233648.00       213479.21
# 16    40  TRANSFER   213553.99  C1249640791           0.00            0.00
# 17   378  CASH_OUT   104393.23  C1099029720           0.00            0.00
# 18   163   CASH_IN   345669.10    C50242324    20481585.13     20827254.23
# 19     1  TRANSFER   215310.30  C1670993182         705.00            0.00
# 20   393  TRANSFER  6763519.01  C1140214351      501691.00            0.00
# 21   261   PAYMENT     2242.07  C1917149964           0.00            0.00
# 22   378   CASH_IN   173150.80   C430991778     8234788.68      8407939.48
# 23   161   PAYMENT     7626.19   C960436380           0.00            0.00
# 24   253  CASH_OUT   560307.38  C1410858025           0.00            0.00
# 25   229  CASH_OUT   238079.14  C2098416935           0.00            0.00
# 26   309   PAYMENT    39471.36   C851475466       51783.00        12311.64
# 27   323  CASH_OUT   159731.45   C454125331           0.00            0.00
# 28   330   CASH_IN   271312.83  C1173973139      144638.00       415950.83
# 29   179   CASH_IN   131801.34   C431746207     2287743.99      2419545.33
# 30    41  TRANSFER   162469.17  C1432705673       15965.00            0.00
# 31   686  CASH_OUT    75295.97   C450707835           0.00            0.00
# 32     1   PAYMENT     5885.56   C840514538           0.00            0.00
# 33   235   PAYMENT     3142.85   C516329438         753.00            0.00
# 34   260  CASH_OUT   125307.24  C1089501872       54617.00            0.00
# 35   371  TRANSFER   529005.25   C509966747       10006.00            0.00
# 36   138  TRANSFER  1023913.18  C1937957967           0.00            0.00
# 37   137   PAYMENT     4878.65   C847578617           0.00            0.00
# 38   185   CASH_IN    39672.61  C2050976015    20779099.45     20818772.06
# 39   329  CASH_OUT    54678.65   C492634764           0.00            0.00
# 40   284  CASH_OUT   266092.71  C1504285594      138906.00            0.00
# 41   256  CASH_OUT   454536.88  C1003241144           0.00            0.00
# 42   258   PAYMENT    25542.89   C346562736      103746.62        78203.73
# 43   238   PAYMENT    33835.16   C139117880           0.00            0.00
# 44     1   PAYMENT     5086.48   C598357562           0.00            0.00
# 45   404   PAYMENT    27751.55   C675941758       10508.00            0.00
# 46   227  CASH_OUT   351053.97   C981103481           0.00            0.00
# 47   153   PAYMENT    25482.12  C1255888368      263399.72       237917.59
# 48   298  TRANSFER  1210884.67  C1839326428       20254.00            0.00
# 49   402  CASH_OUT   225120.56  C1487630208       55622.00            0.00
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0   C1385924981      3175848.97      3422766.41        0               0
# 1    C125997794       653770.69       488193.21        0               0
# 2   M1395131038            0.00            0.00        0               0
# 3   M1924230681            0.00            0.00        0               0
# 4   C1920150261       429733.98       725504.05        0               0
# 5   C1994908118       581593.01       380304.65        0               0
# 6   C1039637819      1462104.72      1757838.38        0               0
# 7   M1690123155            0.00            0.00        0               0
# 8   C1025562950       417436.37       411111.52        0               0
# 9   C1163333876       625268.47       438442.69        0               0
# 10  M2031701840            0.00            0.00        0               0
# 11   C294667510       349097.51        85467.53        0               0
# 12  M1283824466            0.00            0.00        0               0
# 13   C508097468      1239636.22      1494901.32        0               0
# 14   C980016228      1366033.47      1145090.25        0               0
# 15   M467047080            0.00            0.00        0               0
# 16   C694632384      2680813.68      2894367.67        0               0
# 17  C2041453564      1127064.19      1231457.41        0               0
# 18  C1054254937      1208672.88       795967.08        0               0
# 19  C1100439041        22425.00            0.00        0               0
# 20   C245332356            0.00      6763519.01        0               0
# 21  M1127377030            0.00            0.00        0               0
# 22  C1498391408      7830210.09      7657059.29        0               0
# 23  M1861148605            0.00            0.00        0               0
# 24    C33574383       722443.58      1282750.96        0               0
# 25  C1945566121      1065224.84      1303303.98        0               0
# 26  M1066245428            0.00            0.00        0               0
# 27   C431172556      1693178.22      1852909.67        0               0
# 28  C1170426415        95533.00            0.00        0               0
# 29  C1429415136      2127455.63      1995654.29        0               0
# 30  C1653838204            0.00       162469.17        0               0
# 31  C1106440700        89876.04       165172.01        0               0
# 32  M1804441305            0.00            0.00        0               0
# 33  M1068613410            0.00            0.00        0               0
# 34    C90805661            0.00       125307.24        0               0
# 35   C856044772       112953.63       641958.88        0               0
# 36   C399960823      2332208.42      3845253.84        0               0
# 37  M2101543066            0.00            0.00        0               0
# 38  C1763522777       160759.50       121086.89        0               0
# 39  C1474581066       174254.59       228933.24        0               0
# 40  C1557673054       597918.93       864011.64        0               0
# 41   C585731195       532242.37       986779.25        0               0
# 42   M342547982            0.00            0.00        0               0
# 43  M1065087057            0.00            0.00        0               0
# 44  M1593224710            0.00            0.00        0               0
# 45  M1218146950            0.00            0.00        0               0
# 46   C536923665      2707947.84      3059001.81        0               0
# 47   M256072491            0.00            0.00        0               0
# 48  C1782079503       576598.97      1787483.65        0               0
# 49   C179433072            0.00       225120.56        0               0

# %% [markdown]
# ## CHAID Algorithm

# %%
# import pandas as pd
# from chefboost import Chefboost as chef

# # Define the dependent variable and independent variable
# dep_var = "isFraud"
# ind_var = "amount"

# df_sample_subset['isFraud'] = df_sample_subset['isFraud'].astype(int)

# # Define the CHAID algorithm
# config = {'algorithm': 'CHAID'}

# # Define the number of bins to discretize the continuous variable
# num_bins = 5

# # Bin the continuous variable into categories
# df_sample_subset['amount_category'] = pd.cut(df_sample_subset[ind_var], num_bins, labels=False)

# # Fit the decision tree using CHAID algorithm
# model = chef.fit(df_sample_subset, config=config, target_label=dep_var)
# print(model)
# # Print the generated decision tree
# print(model.get_model())

# %%
# from chefboost import Chefboost as chef
# import pandas as pd

# config = {'algorithm': 'CHAID'}
# model = chef.fit(df_sample_subset, config = config, target_label = 'isFraud')
# print(model)

# %% [markdown]
# CHAID
#
# CHAID stands for Chi-square Automated Interaction Detection.
#
# The outcome (dependent) variable can be continuous and categorical. But, predictor (independent) variables are categorical variables only (can be more than 2 categories). It can create multiple splits (more than 2).
#
# When independent variables are continuous, they need to be transformed into categorical variables (bins/groups) before using CHAID.

# %%
df_sample_subset
# Out:
#     step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0    259  CASH_OUT   246917.44  C1498821826           0.00            0.00
# 1    161   CASH_IN   165577.48  C1959842869      242080.31       407657.78
# 2    331   PAYMENT    11147.81   C690176304       21271.00        10123.19
# 3    304   PAYMENT     3758.44  C1065078045           0.00            0.00
# 4    355  CASH_OUT   295770.07   C278303549           0.00            0.00
# 5     95   CASH_IN   201288.36   C665915260     1225323.20      1426611.57
# 6    279  TRANSFER   295733.65     C5902624           0.00            0.00
# 7     43   PAYMENT     8587.65  C1020057479      287197.84       278610.18
# 8    203   CASH_IN     6324.85  C1655576665      637439.64       643764.49
# 9    691   CASH_IN   186825.78   C863136282     4048495.82      4235321.60
# 10   310   PAYMENT    28960.08  C1090990820       49793.00        20832.92
# 11    94   CASH_IN   263629.97  C1969693521     2223455.42      2487085.39
# 12   187   PAYMENT     7708.28  C1453929454           0.00            0.00
# 13   356  CASH_OUT   255265.11   C525712630       79560.00            0.00
# 14   280   CASH_IN   220943.22  C1193018207     1068355.69      1289298.92
# 15    38   PAYMENT    20168.79  C1240927993      233648.00       213479.21
# 16    40  TRANSFER   213553.99  C1249640791           0.00            0.00
# 17   378  CASH_OUT   104393.23  C1099029720           0.00            0.00
# 18   163   CASH_IN   345669.10    C50242324    20481585.13     20827254.23
# 19     1  TRANSFER   215310.30  C1670993182         705.00            0.00
# 20   393  TRANSFER  6763519.01  C1140214351      501691.00            0.00
# 21   261   PAYMENT     2242.07  C1917149964           0.00            0.00
# 22   378   CASH_IN   173150.80   C430991778     8234788.68      8407939.48
# 23   161   PAYMENT     7626.19   C960436380           0.00            0.00
# 24   253  CASH_OUT   560307.38  C1410858025           0.00            0.00
# 25   229  CASH_OUT   238079.14  C2098416935           0.00            0.00
# 26   309   PAYMENT    39471.36   C851475466       51783.00        12311.64
# 27   323  CASH_OUT   159731.45   C454125331           0.00            0.00
# 28   330   CASH_IN   271312.83  C1173973139      144638.00       415950.83
# 29   179   CASH_IN   131801.34   C431746207     2287743.99      2419545.33
# 30    41  TRANSFER   162469.17  C1432705673       15965.00            0.00
# 31   686  CASH_OUT    75295.97   C450707835           0.00            0.00
# 32     1   PAYMENT     5885.56   C840514538           0.00            0.00
# 33   235   PAYMENT     3142.85   C516329438         753.00            0.00
# 34   260  CASH_OUT   125307.24  C1089501872       54617.00            0.00
# 35   371  TRANSFER   529005.25   C509966747       10006.00            0.00
# 36   138  TRANSFER  1023913.18  C1937957967           0.00            0.00
# 37   137   PAYMENT     4878.65   C847578617           0.00            0.00
# 38   185   CASH_IN    39672.61  C2050976015    20779099.45     20818772.06
# 39   329  CASH_OUT    54678.65   C492634764           0.00            0.00
# 40   284  CASH_OUT   266092.71  C1504285594      138906.00            0.00
# 41   256  CASH_OUT   454536.88  C1003241144           0.00            0.00
# 42   258   PAYMENT    25542.89   C346562736      103746.62        78203.73
# 43   238   PAYMENT    33835.16   C139117880           0.00            0.00
# 44     1   PAYMENT     5086.48   C598357562           0.00            0.00
# 45   404   PAYMENT    27751.55   C675941758       10508.00            0.00
# 46   227  CASH_OUT   351053.97   C981103481           0.00            0.00
# 47   153   PAYMENT    25482.12  C1255888368      263399.72       237917.59
# 48   298  TRANSFER  1210884.67  C1839326428       20254.00            0.00
# 49   402  CASH_OUT   225120.56  C1487630208       55622.00            0.00
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0   C1385924981      3175848.97      3422766.41        0               0
# 1    C125997794       653770.69       488193.21        0               0
# 2   M1395131038            0.00            0.00        0               0
# 3   M1924230681            0.00            0.00        0               0
# 4   C1920150261       429733.98       725504.05        0               0
# 5   C1994908118       581593.01       380304.65        0               0
# 6   C1039637819      1462104.72      1757838.38        0               0
# 7   M1690123155            0.00            0.00        0               0
# 8   C1025562950       417436.37       411111.52        0               0
# 9   C1163333876       625268.47       438442.69        0               0
# 10  M2031701840            0.00            0.00        0               0
# 11   C294667510       349097.51        85467.53        0               0
# 12  M1283824466            0.00            0.00        0               0
# 13   C508097468      1239636.22      1494901.32        0               0
# 14   C980016228      1366033.47      1145090.25        0               0
# 15   M467047080            0.00            0.00        0               0
# 16   C694632384      2680813.68      2894367.67        0               0
# 17  C2041453564      1127064.19      1231457.41        0               0
# 18  C1054254937      1208672.88       795967.08        0               0
# 19  C1100439041        22425.00            0.00        0               0
# 20   C245332356            0.00      6763519.01        0               0
# 21  M1127377030            0.00            0.00        0               0
# 22  C1498391408      7830210.09      7657059.29        0               0
# 23  M1861148605            0.00            0.00        0               0
# 24    C33574383       722443.58      1282750.96        0               0
# 25  C1945566121      1065224.84      1303303.98        0               0
# 26  M1066245428            0.00            0.00        0               0
# 27   C431172556      1693178.22      1852909.67        0               0
# 28  C1170426415        95533.00            0.00        0               0
# 29  C1429415136      2127455.63      1995654.29        0               0
# 30  C1653838204            0.00       162469.17        0               0
# 31  C1106440700        89876.04       165172.01        0               0
# 32  M1804441305            0.00            0.00        0               0
# 33  M1068613410            0.00            0.00        0               0
# 34    C90805661            0.00       125307.24        0               0
# 35   C856044772       112953.63       641958.88        0               0
# 36   C399960823      2332208.42      3845253.84        0               0
# 37  M2101543066            0.00            0.00        0               0
# 38  C1763522777       160759.50       121086.89        0               0
# 39  C1474581066       174254.59       228933.24        0               0
# 40  C1557673054       597918.93       864011.64        0               0
# 41   C585731195       532242.37       986779.25        0               0
# 42   M342547982            0.00            0.00        0               0
# 43  M1065087057            0.00            0.00        0               0
# 44  M1593224710            0.00            0.00        0               0
# 45  M1218146950            0.00            0.00        0               0
# 46   C536923665      2707947.84      3059001.81        0               0
# 47   M256072491            0.00            0.00        0               0
# 48  C1782079503       576598.97      1787483.65        0               0
# 49   C179433072            0.00       225120.56        0               0
#
#    amount_category
# 0        100k-500k
# 1        100k-500k
# 2          10k-50k
# 3            0-10k
# 4        100k-500k
# 5        100k-500k
# 6        100k-500k
# 7            0-10k
# 8            0-10k
# 9        100k-500k
# 10         10k-50k
# 11       100k-500k
# 12           0-10k
# 13       100k-500k
# 14       100k-500k
# 15         10k-50k
# 16       100k-500k
# 17       100k-500k
# 18       100k-500k
# 19       100k-500k
# 20          5M-10M
# 21           0-10k
# 22       100k-500k
# 23           0-10k
# 24         500k-1M
# 25       100k-500k
# 26         10k-50k
# 27       100k-500k
# 28       100k-500k
# 29       100k-500k
# 30       100k-500k
# 31        50k-100k
# 32           0-10k
# 33           0-10k
# 34       100k-500k
# 35         500k-1M
# 36           1M-5M
# 37           0-10k
# 38         10k-50k
# 39        50k-100k
# 40       100k-500k
# 41       100k-500k
# 42         10k-50k
# 43         10k-50k
# 44           0-10k
# 45         10k-50k
# 46       100k-500k
# 47         10k-50k
# 48           1M-5M
# 49       100k-500k

# %%
new_df1 = df_sample_subset[['type']].copy()

# %%
new_df1 = pd.concat([new_df1, df_sample_subset[['amount_category', 'isFraud']]], axis=1)

# %%
new_df1
# Out:
#         type amount_category  isFraud
# 0   CASH_OUT       100k-500k        0
# 1    CASH_IN       100k-500k        0
# 2    PAYMENT         10k-50k        0
# 3    PAYMENT           0-10k        0
# 4   CASH_OUT       100k-500k        0
# 5    CASH_IN       100k-500k        0
# 6   TRANSFER       100k-500k        0
# 7    PAYMENT           0-10k        0
# 8    CASH_IN           0-10k        0
# 9    CASH_IN       100k-500k        0
# 10   PAYMENT         10k-50k        0
# 11   CASH_IN       100k-500k        0
# 12   PAYMENT           0-10k        0
# 13  CASH_OUT       100k-500k        0
# 14   CASH_IN       100k-500k        0
# 15   PAYMENT         10k-50k        0
# 16  TRANSFER       100k-500k        0
# 17  CASH_OUT       100k-500k        0
# 18   CASH_IN       100k-500k        0
# 19  TRANSFER       100k-500k        0
# 20  TRANSFER          5M-10M        0
# 21   PAYMENT           0-10k        0
# 22   CASH_IN       100k-500k        0
# 23   PAYMENT           0-10k        0
# 24  CASH_OUT         500k-1M        0
# 25  CASH_OUT       100k-500k        0
# 26   PAYMENT         10k-50k        0
# 27  CASH_OUT       100k-500k        0
# 28   CASH_IN       100k-500k        0
# 29   CASH_IN       100k-500k        0
# 30  TRANSFER       100k-500k        0
# 31  CASH_OUT        50k-100k        0
# 32   PAYMENT           0-10k        0
# 33   PAYMENT           0-10k        0
# 34  CASH_OUT       100k-500k        0
# 35  TRANSFER         500k-1M        0
# 36  TRANSFER           1M-5M        0
# 37   PAYMENT           0-10k        0
# 38   CASH_IN         10k-50k        0
# 39  CASH_OUT        50k-100k        0
# 40  CASH_OUT       100k-500k        0
# 41  CASH_OUT       100k-500k        0
# 42   PAYMENT         10k-50k        0
# 43   PAYMENT         10k-50k        0
# 44   PAYMENT           0-10k        0
# 45   PAYMENT         10k-50k        0
# 46  CASH_OUT       100k-500k        0
# 47   PAYMENT         10k-50k        0
# 48  TRANSFER           1M-5M        0
# 49  CASH_OUT       100k-500k        0

# %%
# Convert numerical columns to strings
for col in new_df1.select_dtypes(include=['float', 'int']):
    new_df1[col] = new_df1[col].astype(str)

# %%
from chefboost import Chefboost as chef
import pandas as pd

# Convert the 'amount' variable to categorical using pd.cut
#df_sample_subset['amount_category'] = pd.cut(df_sample_subset['amount'], bins=[0, 10000, 50000, 100000, 500000, 1000000, 5000000, 10000000], labels=['0-10k', '10k-50k', '50k-100k', '100k-500k', '500k-1M', '1M-5M', '5M-10M'])

config = {'algorithm': 'CHAID'}
model = chef.fit(new_df1, config = config, target_label = 'isFraud')
print(model)
# Out:
# [INFO]:  4 CPU cores will be allocated in parallel running
# CHAID  tree is going to be built...
# -------------------------
# finished in  0.2705202102661133  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  100.0 % on  50  instances
# Labels:  ['0']
# Confusion matrix:  [[50]]
# Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
# {'trees': [<module 'outputs/rules/rules' from 'C:\\Users\\23059\\OneDrive\\Desktop\\FinalYearProject\\outputs/rules/rules.py'>], 'alphas': [], 'config': {'algorithm': 'CHAID', 'enableRandomForest': False, 'num_of_trees': 5, 'enableMultitasking': False, 'enableGBM': False, 'epochs': 10, 'learning_rate': 1, 'max_depth': 3, 'enableAdaboost': False, 'num_of_weak_classifier': 4, 'enableParallelism': True, 'num_cores': 4}, 'nan_values': [['amount_category', None]]}

# %%
model.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10912\690027505.py in <module>
# ----> 1 model.plot()
#
# AttributeError: 'dict' object has no attribute 'plot'

# %% [markdown]
# ## Run apriori after chaid
